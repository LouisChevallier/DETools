# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
import pandas as pd
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient("mongo")
database = client.exercices
print(client.database_names())
collection = database['kickstarter']
# Out:
# ['admin', 'config', 'exercices', 'local', 'series']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks
# Out:
#                 ID                                               name  \
# 0        872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1       1326492673                                    Ohceola jewelry
# 2       1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3        156812982  SketchPlanner: Create and Plan- all in one bea...
# 4       1835968190    Proven sales with custom motorcycle accessories
# 5       1771789139                                   Room For Growth!
# 6       1301627822          Build a mini Udemy with Laravel and Vuejs
# 7        881336601                                         Applitizer
# 8       1669374237  Help I Am Wolves fund their first album "ABCD"...
# 9        556821416        Eco  Bamboo Underwear funding....GOT WOOD ?
# 10       160394496                         SHAKTI: The Power of Woman
# 11      1248488072                                   Coast to Coaster
# 12       895565490                   Frostbite Gaming - Minecraft HUB
# 13      1165822076                              Support Ramsort album
# 14       424612381                                 Red No. 95 Issue 3
# 15      1182908609                               Alice In Wonderland!
# 16       206040356                                 Un piano : 150 Pas
# 17       396454289  Operation Penumbra: A WWII Supernatural Advent...
# 18      1522195027                                           Emma Rae
# 19      1429288669  Strange Occurrences: Performances for Non-Thea...
# 20      1441999253                       Ancient Ruins II Base Series
# 21      1202442815                       The Craziest Thing Webseries
# 22      2116917173                       Look UP! To this nice shirt!
# 23      2117684680  Ghost Nest: Giving the Power of Design Back to...
# 24       350628546                                    Elli (Canceled)
# 25        35969505  States, Firms, & Households: the search for eq...
# 26      1849047042  Central Florida Artisans' Guild: Community Growth
# 27       295864582                       Frankenstein Soft Enamel Pin
# 28       496463082  qualMeter XT: Greater Experience on Cable/Char...
# 29      1390262683  Candy Coburn - "THE GOOD LIFE" New Soul Rockin...
# ...            ...                                                ...
# 149970    78503973                                 Safe House Project
# 149971  2060030062  GlowWormz: Translucent Stickers for your Mac l...
# 149972   367266483                 The imaginary construction company
# 149973  1260789943             Harley Mae - Custom Artisan Medallions
# 149974  1059655537              VGA Planets "Nu", the official remake
# 149975  1184032892       Homemade Chocolate In The RAW - Recipe Book!
# 149976  1948932898  Syrian Children's Play: Romeo & Juliet Separat...
# 149977   283237168   A very special NEW stripped-down Sea Wolf ALBUM!
# 149978  1491659558        Album/Video/Documentary and Tour Experience
# 149979   303714539                    Amanda Christine Studio Project
# 149980  1351511666  Tabletop Gamer Mouse Mats - Including Cthulhu ...
# 149981  1466935897                 CLASSICAL IMPROVISATION: new album
# 149982  1591313430                        Mill House Brews (Canceled)
# 149983   192796167  Glass In The Sky: A new music video by Tyler S...
# 149984  1105160938  "6:25" - an indie short film (POST-PRODUCTION ...
# 149985  2057605332                                  The Dangerous Sea
# 149986   548892062  Pocket: 6-in-1 Portable Charging Dock for Appl...
# 149987   514989474                                 The Bigger Picture
# 149988   707367720        SAILOR SENSHI - HENSHIN YO! HARD ENAMEL PIN
# 149989   244115481                                    CAROLS IN A BOX
# 149990   897291253                         It Came from the Fridge!!!
# 149991  1975560993        Paul Horner CD - I Gave It Everything I Had
# 149992   192005621  "The Icing" - an erotic thriller starring Jim ...
# 149993    81312192  "DOG EAT DOG" - A short comedy starring Zachar...
# 149994   548612847                  The Farm - Cooked Up by Culinaria
# 149995   574841011  Scutes Headphones - A new way to listen to you...
# 149996   235190237                               My Drunk @$$ Reviews
# 149997   758540498          Freedom Planet - High Speed Platform Game
# 149998  1624952469                                      Clown vs Mime
# 149999   891117261                            Striker's Cafe & Bakery
#
#                category main_category currency    deadline    goal  \
# 0                  Rock         Music      USD  2011-09-16    2000
# 1               Fashion       Fashion      USD  2012-08-22   18000
# 2        Tabletop Games         Games      USD  2016-07-19    2000
# 3             Art Books    Publishing      USD  2017-09-27   13000
# 4             Sculpture           Art      CAD  2016-02-24    5000
# 5               Couture       Fashion      USD  2016-05-02    2000
# 6                   Web    Technology      CAD  2018-01-11    3000
# 7              Software    Technology      HKD  2017-08-20  100000
# 8                 Music         Music      EUR  2017-12-04    1000
# 9               Fashion       Fashion      GBP  2012-12-13    9500
# 10          Documentary  Film & Video      USD  2012-03-13   15000
# 11                Print    Journalism      USD  2017-06-21   25000
# 12          Video Games         Games      GBP  2014-11-26     400
# 13                 Rock         Music      NOK  2015-05-03  150000
# 14          Comic Books        Comics      USD  2017-08-10     800
# 15              Theater       Theater      USD  2012-06-15     220
# 16         Performances         Dance      CAD  2017-09-03    1500
# 17               Comics        Comics      USD  2014-01-17   15000
# 18                Drama  Film & Video      USD  2017-07-27   12000
# 19              Theater       Theater      USD  2010-09-22    3000
# 20       Tabletop Games         Games      USD  2014-11-06    1800
# 21            Webseries  Film & Video      USD  2014-03-22   30000
# 22              Fashion       Fashion      USD  2012-11-10    3700
# 23               Design        Design      USD  2010-11-17   18729
# 24               Crafts        Crafts      USD  2014-11-03    5000
# 25          Video Games         Games      CAD  2016-01-22     100
# 26                  DIY        Crafts      USD  2015-05-12    2000
# 27          Accessories       Fashion      USD  2017-09-29     215
# 28              Gadgets    Technology      CAD  2017-06-05    5000
# 29                Music         Music      USD  2016-06-08   15000
# ...                 ...           ...      ...         ...     ...
# 149970          Hip-Hop         Music      USD  2016-12-17    5000
# 149971   Graphic Design        Design      USD  2012-09-16    1250
# 149972      Digital Art           Art      EUR  2017-04-02     300
# 149973          Jewelry       Fashion      USD  2015-02-04     150
# 149974      Video Games         Games      USD  2010-07-30   10000
# 149975       Publishing    Publishing      USD  2012-11-18    1700
# 149976            Plays       Theater      USD  2015-03-11    4000
# 149977       Indie Rock         Music      USD  2013-10-01   50000
# 149978          Hip-Hop         Music      SEK  2016-01-01   20000
# 149979   Country & Folk         Music      USD  2012-10-11    3500
# 149980   Tabletop Games         Games      GBP  2014-03-27     220
# 149981            Music         Music      USD  2016-05-02   12000
# 149982           Drinks          Food      AUD  2014-12-21  250000
# 149983           Shorts  Film & Video      USD  2012-09-12    3000
# 149984           Shorts  Film & Video      USD  2013-10-22    2500
# 149985   Tabletop Games         Games      USD  2016-06-07    5000
# 149986          Gadgets    Technology      AUD  2015-12-11  112000
# 149987             Rock         Music      USD  2015-08-25    7000
# 149988              Art           Art      EUR  2017-10-16     660
# 149989  Classical Music         Music      GBP  2013-05-04     700
# 149990              Art           Art      CAD  2014-09-22    7500
# 149991            Music         Music      USD  2015-11-20    1000
# 149992   Narrative Film  Film & Video      USD  2014-04-12    2000
# 149993           Shorts  Film & Video      USD  2011-12-08    7500
# 149994            Farms          Food      USD  2016-09-27   25000
# 149995   Product Design        Design      USD  2014-11-14   40000
# 149996        Webseries  Film & Video      USD  2012-05-18    1000
# 149997      Video Games         Games      USD  2013-02-15    2000
# 149998        Webseries  Film & Video      USD  2011-05-27    1000
# 149999      Food Trucks          Food      USD  2016-05-02   20000
#
#                    launched  pledged       state backers country usd pledged  \
# 0       2011-08-17 06:31:31     1145    canceled      24      US        1145
# 1       2012-07-23 20:46:48     1851      failed      28      US        1851
# 2       2016-07-01 21:55:54     7534  successful     254      US        3796
# 3       2017-08-28 15:47:02    16298  successful     367      US        2670
# 4       2016-01-25 17:37:10        1      failed       1      CA    0.708148
# 5       2016-04-11 18:15:00        6      failed       2      US           6
# 6       2017-12-12 01:37:26      155        live       7      CA      15.564
# 7       2017-07-21 16:50:05     1000      failed       1      HK     128.085
# 8       2017-10-27 16:55:47     1465  successful      46      BE           0
# 9       2012-11-13 10:58:34     1212      failed      43      GB     1928.14
# 10      2012-01-13 16:27:16  18361.9  successful     126      US     18361.9
# 11      2017-05-07 06:05:42        1      failed       1      US           0
# 12      2014-10-17 11:25:49       10      failed       1      GB     15.9922
# 13      2015-04-03 14:24:19       10      failed       2      NO     1.24556
# 14      2017-07-11 08:16:21      955  successful      34      US          35
# 15      2012-05-16 05:37:08      320  successful      13      US         320
# 16      2017-07-05 21:52:43     1540  successful      31      CA           0
# 17      2013-12-18 23:19:02     5035      failed      81      US        5035
# 18      2017-06-27 18:00:25    13415  successful     100      US        1750
# 19      2010-07-23 23:30:10  3080.98  successful      59      US     3080.98
# 20      2014-10-22 14:58:46  5630.95  successful      88      US     5630.95
# 21      2014-01-22 00:13:15      300      failed       2      US         300
# 22      2012-09-26 06:15:44      203      failed       7      US         203
# 23      2010-10-08 01:29:29     1781    canceled      32      US        1781
# 24      2014-09-04 00:10:14      121    canceled       3      US         121
# 25      2015-12-23 07:35:24        0    canceled       0      CA           0
# 26      2015-04-22 18:59:35      121      failed       4      US         121
# 27      2017-09-22 22:25:58       18      failed       1      US           0
# 28      2017-05-06 15:13:17    10655  successful     222      CA     5300.35
# 29      2016-05-10 12:43:24    15530  successful     151      US       15530
# ...                     ...      ...         ...     ...     ...         ...
# 149970  2016-11-23 17:04:16     6525  successful      46      US           0
# 149971  2012-08-14 22:23:47     1374  successful      93      US        1374
# 149972  2017-02-27 17:49:08      240    canceled       3      ES           0
# 149973  2015-01-05 05:01:02      349  successful      10      US         349
# 149974  2010-05-30 19:21:47     2433      failed      35      US        2433
# 149975  2012-10-19 18:59:43  2572.17  successful      45      US     2572.17
# 149976  2015-02-09 05:26:23     4090  successful      48      US        4090
# 149977  2013-08-19 20:08:28  63169.6  successful    1169      US     63169.6
# 149978  2015-11-02 22:13:46        0      failed       0      SE           0
# 149979  2012-09-18 03:15:54     3500  successful      25      US        3500
# 149980  2014-03-04 00:06:28       10    canceled       1      GB     16.7439
# 149981  2016-04-07 18:59:28    12362  successful      81      US       12362
# 149982  2014-10-22 01:39:52        0    canceled       0      AU           0
# 149983  2012-08-13 20:06:51      100      failed       1      US         100
# 149984  2013-10-02 15:27:42  3745.54  successful      78      US     3745.54
# 149985  2016-05-07 18:33:05     2282      failed      50      US        2282
# 149986  2015-11-10 14:27:35   113485  successful     306      AU     80068.7
# 149987  2015-07-26 21:07:38       30      failed       1      US          30
# 149988  2017-10-06 00:20:42      108      failed       4      IT     89.4333
# 149989  2013-04-04 13:19:19        0      failed       0      GB           0
# 149990  2014-08-08 03:39:45   613.14      failed      16      CA     559.549
# 149991  2015-10-21 16:00:31     2272  successful      81      US        2272
# 149992  2014-03-18 02:36:58      420      failed      16      US         420
# 149993  2011-11-08 18:01:41  30204.8  successful     307      US     30204.8
# 149994  2016-08-13 17:35:43     1786      failed       8      US           0
# 149995  2014-10-14 20:44:37     3664    canceled      43      US        3664
# 149996  2012-04-18 04:42:47        0      failed       0      US           0
# 149997  2013-01-16 00:53:32  25472.7  successful    1105      US     25472.7
# 149998  2011-04-27 01:22:52       76      failed       3      US          76
# 149999  2016-04-03 08:01:57       29      failed       3      US          29
#
#         usd_pledged_real
# 0            1145.000000
# 1            1851.000000
# 2            7534.000000
# 3           16298.000000
# 4               0.738225
# 5               6.000000
# 6             123.811806
# 7             127.831467
# 8            1720.210418
# 9            1953.672808
# 10          18361.890000
# 11              1.000000
# 12             15.695877
# 13              1.338778
# 14            955.000000
# 15            320.000000
# 16           1274.096136
# 17           5035.000000
# 18          13415.000000
# 19           3080.980000
# 20           5630.950000
# 21            300.000000
# 22            203.000000
# 23           1781.000000
# 24            121.000000
# 25              0.000000
# 26            121.000000
# 27             18.000000
# 28           7887.334370
# 29          15530.000000
# ...                  ...
# 149970       6525.000000
# 149971       1374.000000
# 149972        255.121023
# 149973        349.000000
# 149974       2433.000000
# 149975       2572.170000
# 149976       4090.000000
# 149977      63169.590000
# 149978          0.000000
# 149979       3500.000000
# 149980         16.633123
# 149981      12362.000000
# 149982          0.000000
# 149983        100.000000
# 149984       3745.540000
# 149985       2282.000000
# 149986      81861.790377
# 149987         30.000000
# 149988        127.633927
# 149989          0.000000
# 149990        551.781857
# 149991       2272.000000
# 149992        420.000000
# 149993      30204.780000
# 149994       1786.000000
# 149995       3664.000000
# 149996          0.000000
# 149997      25472.690000
# 149998         76.000000
# 149999         29.000000
#
# [150000 rows x 14 columns]

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_ks['launched'] = pd.to_datetime(df_ks['launched'], errors='coerce')
df_ks = df_ks.dropna(subset=['launched'])
df_ks.rename(columns={'ID':'_id'}, inplace=True)
l_d =df_ks.to_dict(orient='records')

# %% [markdown]
# ### Importer les données

# %%
collection.delete_many({})
collection.insert_many(l_d)

# %%
print(client.database_names())
# Out:
# ['admin', 'config', 'exercices', 'local', 'series']

# %%
l_d
# Out:
# [{'_id': 872782264,
#   'name': 'Scott Cooper\'s Solo CD "A Leg Trick" (Canceled)',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2011-09-16',
#   'goal': 2000.0,
#   'launched': Timestamp('2011-08-17 06:31:31'),
#   'pledged': 1145.0,
#   'state': 'canceled',
#   'backers': 24,
#   'country': 'US',
#   'usd pledged': 1145.0,
#   'usd_pledged_real': 1145.0},
#  {'_id': 1326492673,
#   'name': 'Ohceola jewelry',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2012-08-22',
#   'goal': 18000.0,
#   'launched': Timestamp('2012-07-23 20:46:48'),
#   'pledged': 1851.0,
#   'state': 'failed',
#   'backers': 28,
#   'country': 'US',
#   'usd pledged': 1851.0,
#   'usd_pledged_real': 1851.0},
#  {'_id': 1688410639,
#   'name': 'Sluff Off & Harald: Two latest EGGs are Classics "old & new"',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-07-19',
#   'goal': 2000.0,
#   'launched': Timestamp('2016-07-01 21:55:54'),
#   'pledged': 7534.0,
#   'state': 'successful',
#   'backers': 254,
#   'country': 'US',
#   'usd pledged': 3796.0,
#   'usd_pledged_real': 7534.0},
#  {'_id': 156812982,
#   'name': 'SketchPlanner: Create and Plan- all in one beautiful book!',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-09-27',
#   'goal': 13000.0,
#   'launched': Timestamp('2017-08-28 15:47:02'),
#   'pledged': 16298.0,
#   'state': 'successful',
#   'backers': 367,
#   'country': 'US',
#   'usd pledged': 2670.0,
#   'usd_pledged_real': 16298.0},
#  {'_id': 1835968190,
#   'name': 'Proven sales with custom motorcycle accessories',
#   'category': 'Sculpture',
#   'main_category': 'Art',
#   'currency': 'CAD',
#   'deadline': '2016-02-24',
#   'goal': 5000.0,
#   'launched': Timestamp('2016-01-25 17:37:10'),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'CA',
#   'usd pledged': 0.70814759,
#   'usd_pledged_real': 0.7382253063635021},
#  {'_id': 1771789139,
#   'name': 'Room For Growth!',
#   'category': 'Couture',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-05-02',
#   'goal': 2000.0,
#   'launched': Timestamp('2016-04-11 18:15:00'),
#   'pledged': 6.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 6.0,
#   'usd_pledged_real': 6.0},
#  {'_id': 1301627822,
#   'name': 'Build a mini Udemy with Laravel and Vuejs',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2018-01-11',
#   'goal': 3000.0,
#   'launched': Timestamp('2017-12-12 01:37:26'),
#   'pledged': 155.0,
#   'state': 'live',
#   'backers': 7,
#   'country': 'CA',
#   'usd pledged': 15.5639964,
#   'usd_pledged_real': 123.81180605479669},
#  {'_id': 881336601,
#   'name': 'Applitizer',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'HKD',
#   'deadline': '2017-08-20',
#   'goal': 100000.0,
#   'launched': Timestamp('2017-07-21 16:50:05'),
#   'pledged': 1000.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'HK',
#   'usd pledged': 128.08538,
#   'usd_pledged_real': 127.83146699391523},
#  {'_id': 1669374237,
#   'name': 'Help I Am Wolves fund their first album "ABCD" on 12" vinyl!',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2017-12-04',
#   'goal': 1000.0,
#   'launched': Timestamp('2017-10-27 16:55:47'),
#   'pledged': 1465.0,
#   'state': 'successful',
#   'backers': 46,
#   'country': 'BE',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1720.2104175473205},
#  {'_id': 556821416,
#   'name': 'Eco  Bamboo Underwear funding....GOT WOOD ?',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'GBP',
#   'deadline': '2012-12-13',
#   'goal': 9500.0,
#   'launched': Timestamp('2012-11-13 10:58:34'),
#   'pledged': 1212.0,
#   'state': 'failed',
#   'backers': 43,
#   'country': 'GB',
#   'usd pledged': 1928.13711852,
#   'usd_pledged_real': 1953.6728081628705},
#  {'_id': 160394496,
#   'name': 'SHAKTI: The Power of Woman',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-03-13',
#   'goal': 15000.0,
#   'launched': Timestamp('2012-01-13 16:27:16'),
#   'pledged': 18361.89,
#   'state': 'successful',
#   'backers': 126,
#   'country': 'US',
#   'usd pledged': 18361.89,
#   'usd_pledged_real': 18361.89},
#  {'_id': 1248488072,
#   'name': 'Coast to Coaster',
#   'category': 'Print',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2017-06-21',
#   'goal': 25000.0,
#   'launched': Timestamp('2017-05-07 06:05:42'),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 895565490,
#   'name': 'Frostbite Gaming - Minecraft HUB',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2014-11-26',
#   'goal': 400.0,
#   'launched': Timestamp('2014-10-17 11:25:49'),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'GB',
#   'usd pledged': 15.9921958,
#   'usd_pledged_real': 15.695876693192696},
#  {'_id': 1165822076,
#   'name': 'Support Ramsort album',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'NOK',
#   'deadline': '2015-05-03',
#   'goal': 150000.0,
#   'launched': Timestamp('2015-04-03 14:24:19'),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'NO',
#   'usd pledged': 1.2455610000000001,
#   'usd_pledged_real': 1.3387776959635849},
#  {'_id': 424612381,
#   'name': 'Red No. 95 Issue 3',
#   'category': 'Comic Books',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2017-08-10',
#   'goal': 800.0,
#   'launched': Timestamp('2017-07-11 08:16:21'),
#   'pledged': 955.0,
#   'state': 'successful',
#   'backers': 34,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 955.0},
#  {'_id': 1182908609,
#   'name': 'Alice In Wonderland!',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2012-06-15',
#   'goal': 220.0,
#   'launched': Timestamp('2012-05-16 05:37:08'),
#   'pledged': 320.0,
#   'state': 'successful',
#   'backers': 13,
#   'country': 'US',
#   'usd pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'_id': 206040356,
#   'name': 'Un piano : 150 Pas',
#   'category': 'Performances',
#   'main_category': 'Dance',
#   'currency': 'CAD',
#   'deadline': '2017-09-03',
#   'goal': 1500.0,
#   'launched': Timestamp('2017-07-05 21:52:43'),
#   'pledged': 1540.0,
#   'state': 'successful',
#   'backers': 31,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1274.0961363448332},
#  {'_id': 396454289,
#   'name': 'Operation Penumbra: A WWII Supernatural Adventure, Vol. 1',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2014-01-17',
#   'goal': 15000.0,
#   'launched': Timestamp('2013-12-18 23:19:02'),
#   'pledged': 5035.0,
#   'state': 'failed',
#   'backers': 81,
#   'country': 'US',
#   'usd pledged': 5035.0,
#   'usd_pledged_real': 5035.0},
#  {'_id': 1522195027,
#   'name': 'Emma Rae',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-07-27',
#   'goal': 12000.0,
#   'launched': Timestamp('2017-06-27 18:00:25'),
#   'pledged': 13415.0,
#   'state': 'successful',
#   'backers': 100,
#   'country': 'US',
#   'usd pledged': 1750.0,
#   'usd_pledged_real': 13415.0},
#  {'_id': 1429288669,
#   'name': 'Strange Occurrences: Performances for Non-Theater Spaces',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2010-09-22',
#   'goal': 3000.0,
#   'launched': Timestamp('2010-07-23 23:30:10'),
#   'pledged': 3080.98,
#   'state': 'successful',
#   'backers': 59,
#   'country': 'US',
#   'usd pledged': 3080.98,
#   'usd_pledged_real': 3080.98},
#  {'_id': 1441999253,
#   'name': 'Ancient Ruins II Base Series',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-11-06',
#   'goal': 1800.0,
#   'launched': Timestamp('2014-10-22 14:58:46'),
#   'pledged': 5630.95,
#   'state': 'successful',
#   'backers': 88,
#   'country': 'US',
#   'usd pledged': 5630.95,
#   'usd_pledged_real': 5630.95},
#  {'_id': 1202442815,
#   'name': 'The Craziest Thing Webseries',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-03-22',
#   'goal': 30000.0,
#   'launched': Timestamp('2014-01-22 00:13:15'),
#   'pledged': 300.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 300.0,
#   'usd_pledged_real': 300.0},
#  {'_id': 2116917173,
#   'name': 'Look UP! To this nice shirt!',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2012-11-10',
#   'goal': 3700.0,
#   'launched': Timestamp('2012-09-26 06:15:44'),
#   'pledged': 203.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 203.0,
#   'usd_pledged_real': 203.0},
#  {'_id': 2117684680,
#   'name': 'Ghost Nest: Giving the Power of Design Back to the Consumer (Canceled)',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2010-11-17',
#   'goal': 18729.0,
#   'launched': Timestamp('2010-10-08 01:29:29'),
#   'pledged': 1781.0,
#   'state': 'canceled',
#   'backers': 32,
#   'country': 'US',
#   'usd pledged': 1781.0,
#   'usd_pledged_real': 1781.0},
#  {'_id': 350628546,
#   'name': 'Elli (Canceled)',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2014-11-03',
#   'goal': 5000.0,
#   'launched': Timestamp('2014-09-04 00:10:14'),
#   'pledged': 121.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 121.0,
#   'usd_pledged_real': 121.0},
#  {'_id': 35969505,
#   'name': 'States, Firms, & Households: the search for equilibrium (2)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'CAD',
#   'deadline': '2016-01-22',
#   'goal': 100.0,
#   'launched': Timestamp('2015-12-23 07:35:24'),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1849047042,
#   'name': "Central Florida Artisans' Guild: Community Growth",
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2015-05-12',
#   'goal': 2000.0,
#   'launched': Timestamp('2015-04-22 18:59:35'),
#   'pledged': 121.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 121.0,
#   'usd_pledged_real': 121.0},
#  {'_id': 295864582,
#   'name': 'Frankenstein Soft Enamel Pin',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-09-29',
#   'goal': 215.0,
#   'launched': Timestamp('2017-09-22 22:25:58'),
#   'pledged': 18.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 18.0},
#  {'_id': 496463082,
#   'name': 'qualMeter XT: Greater Experience on Cable/Charger Testing',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2017-06-05',
#   'goal': 5000.0,
#   'launched': Timestamp('2017-05-06 15:13:17'),
#   'pledged': 10655.0,
#   'state': 'successful',
#   'backers': 222,
#   'country': 'CA',
#   'usd pledged': 5300.34825892,
#   'usd_pledged_real': 7887.334369679473},
#  {'_id': 1390262683,
#   'name': 'Candy Coburn - "THE GOOD LIFE" New Soul Rockin\' Studio Album',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2016-06-08',
#   'goal': 15000.0,
#   'launched': Timestamp('2016-05-10 12:43:24'),
#   'pledged': 15530.0,
#   'state': 'successful',
#   'backers': 151,
#   'country': 'US',
#   'usd pledged': 15530.0,
#   'usd_pledged_real': 15530.0},
#  {'_id': 1041882251,
#   'name': "Gentlemen's Bar",
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-07-16',
#   'goal': 4000.0,
#   'launched': Timestamp('2016-06-16 20:31:11'),
#   'pledged': 613.0,
#   'state': 'failed',
#   'backers': 25,
#   'country': 'US',
#   'usd pledged': 433.0,
#   'usd_pledged_real': 613.0},
#  {'_id': 1130940376,
#   'name': 'A Sickle Life',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-07-01',
#   'goal': 5000.0,
#   'launched': Timestamp('2016-06-01 15:15:40'),
#   'pledged': 60.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': 186326896,
#   'name': 'NYC Type',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2012-10-30',
#   'goal': 10000.0,
#   'launched': Timestamp('2012-10-11 00:28:31'),
#   'pledged': 10106.0,
#   'state': 'successful',
#   'backers': 179,
#   'country': 'US',
#   'usd pledged': 10106.0,
#   'usd_pledged_real': 10106.0},
#  {'_id': 1025722498,
#   'name': 'PatentSlice.com-Automated Patent Drill-Down & Analysis Tool',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-03-23',
#   'goal': 5000.0,
#   'launched': Timestamp('2017-02-21 21:37:27'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1493170888,
#   'name': 'The Birdsongs - New CD Project',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2011-04-28',
#   'goal': 5000.0,
#   'launched': Timestamp('2011-03-18 02:50:18'),
#   'pledged': 6357.0,
#   'state': 'successful',
#   'backers': 83,
#   'country': 'US',
#   'usd pledged': 6357.0,
#   'usd_pledged_real': 6357.0},
#  {'_id': 1007463174,
#   'name': 'Brazilian pop artist Kiko London Tour support',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-04-17',
#   'goal': 8000.0,
#   'launched': Timestamp('2017-03-14 19:22:11'),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 2143760539,
#   'name': 'Emissary - Tabletop RPG',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2016-03-21',
#   'goal': 5000.0,
#   'launched': Timestamp('2016-02-20 15:46:23'),
#   'pledged': 9324.0,
#   'state': 'successful',
#   'backers': 334,
#   'country': 'GB',
#   'usd pledged': 13350.07578744,
#   'usd_pledged_real': 13174.888019103872},
#  {'_id': 2062002375,
#   'name': 'Desktop Museum of Card Art',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-04-11',
#   'goal': 1600.0,
#   'launched': Timestamp('2014-03-12 22:33:56'),
#   'pledged': 587.0,
#   'state': 'failed',
#   'backers': 28,
#   'country': 'US',
#   'usd pledged': 587.0,
#   'usd_pledged_real': 587.0},
#  {'_id': 1183084584,
#   'name': 'Act for Change: Healing Minds',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'GBP',
#   'deadline': '2014-08-13',
#   'goal': 16000.0,
#   'launched': Timestamp('2014-07-14 22:47:13'),
#   'pledged': 1638.0,
#   'state': 'failed',
#   'backers': 38,
#   'country': 'GB',
#   'usd pledged': 2804.4439605000002,
#   'usd_pledged_real': 2733.827358301622},
#  {'_id': 1977195934,
#   'name': 'Book: Outrageously (un)loved - The fight against selfhatred',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2015-03-30',
#   'goal': 900.0,
#   'launched': Timestamp('2015-01-29 23:17:48'),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'NL',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1035882318,
#   'name': 'Help match our 2nd NEA grant for Glory Denied',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2015-11-12',
#   'goal': 2500.0,
#   'launched': Timestamp('2015-10-26 14:06:42'),
#   'pledged': 2650.0,
#   'state': 'successful',
#   'backers': 29,
#   'country': 'US',
#   'usd pledged': 2650.0,
#   'usd_pledged_real': 2650.0},
#  {'_id': 1021441525,
#   'name': 'The Alchemy of Art Book',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'currency': 'CAD',
#   'deadline': '2016-12-22',
#   'goal': 7770.0,
#   'launched': Timestamp('2016-11-28 02:06:47'),
#   'pledged': 25.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 18.499334023975138},
#  {'_id': 1691723287,
#   'name': 'The Om Space',
#   'category': 'Civic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-07-08',
#   'goal': 15000.0,
#   'launched': Timestamp('2016-06-08 18:13:45'),
#   'pledged': 1512.0,
#   'state': 'failed',
#   'backers': 28,
#   'country': 'US',
#   'usd pledged': 1512.0,
#   'usd_pledged_real': 1512.0},
#  {'_id': 680665134,
#   'name': 'Open Source Gemini Simulator',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-08-17',
#   'goal': 1675.0,
#   'launched': Timestamp('2017-07-18 19:37:33'),
#   'pledged': 1685.0,
#   'state': 'successful',
#   'backers': 28,
#   'country': 'US',
#   'usd pledged': 135.0,
#   'usd_pledged_real': 1685.0},
#  {'_id': 1864901261,
#   'name': 'Tenabris Ides',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-03-14',
#   'goal': 1500.0,
#   'launched': Timestamp('2015-02-14 03:53:39'),
#   'pledged': 16.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 16.0,
#   'usd_pledged_real': 16.0},
#  {'_id': 519449839,
#   'name': 'Johnny P - Resurrected (Album)',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-08-07',
#   'goal': 750.0,
#   'launched': Timestamp('2013-07-08 22:54:55'),
#   'pledged': 26.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 26.0,
#   'usd_pledged_real': 26.0},
#  {'_id': 1875047349,
#   'name': 'Hope for our youth today',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2014-08-20',
#   'goal': 6700.0,
#   'launched': Timestamp('2014-07-21 20:03:14'),
#   'pledged': 13.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 13.0,
#   'usd_pledged_real': 13.0},
#  {'_id': 217543389,
#   'name': 'The uKeg Pressurized Growler for Fresh Beer',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-12-08',
#   'goal': 75000.0,
#   'launched': Timestamp('2014-10-15 06:34:48'),
#   'pledged': 1559525.68,
#   'state': 'successful',
#   'backers': 10293,
#   'country': 'US',
#   'usd pledged': 1559525.68,
#   'usd_pledged_real': 1559525.68},
#  {'_id': 1263082934,
#   'name': 'STEAM for Students',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-14',
#   'goal': 5000.0,
#   'launched': Timestamp('2014-08-15 04:46:08'),
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 764437823,
#   'name': 'Cold Waters, Warm Hearts: Portraits of Women Who Fly-Fish',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-06-28',
#   'goal': 10000.0,
#   'launched': Timestamp('2016-05-19 02:48:20'),
#   'pledged': 586.0,
#   'state': 'failed',
#   'backers': 15,
#   'country': 'US',
#   'usd pledged': 586.0,
#   'usd_pledged_real': 586.0},
#  {'_id': 1341393677,
#   'name': 'Sure Set Hook',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-01-15',
#   'goal': 15000.0,
#   'launched': Timestamp('2014-12-16 15:43:20'),
#   'pledged': 100.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'_id': 1149469807,
#   'name': 'Bespoke by Demian Custom Menswear',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-09-10',
#   'goal': 10000.0,
#   'launched': Timestamp('2015-08-11 21:43:39'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1968352897,
#   'name': 'Renewable Soy + American Made Candles = LOVE',
#   'category': 'Candles',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2012-02-23',
#   'goal': 1000.0,
#   'launched': Timestamp('2012-01-24 02:19:34'),
#   'pledged': 2325.0,
#   'state': 'successful',
#   'backers': 39,
#   'country': 'US',
#   'usd pledged': 2325.0,
#   'usd_pledged_real': 2325.0},
#  {'_id': 693501911,
#   'name': 'Spray Art on canvas series',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'GBP',
#   'deadline': '2015-05-14',
#   'goal': 5000.0,
#   'launched': Timestamp('2015-04-14 13:33:36'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 397524601,
#   'name': "Make Rubulad's Dream Home Come True",
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2011-12-09',
#   'goal': 35000.0,
#   'launched': Timestamp('2011-11-11 18:49:35'),
#   'pledged': 37248.52,
#   'state': 'successful',
#   'backers': 733,
#   'country': 'US',
#   'usd pledged': 37248.52,
#   'usd_pledged_real': 37248.52},
#  {'_id': 520797301,
#   'name': 'Bad Habit Beers',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-10-17',
#   'goal': 25000.0,
#   'launched': Timestamp('2015-09-17 21:35:33'),
#   'pledged': 7522.0,
#   'state': 'failed',
#   'backers': 76,
#   'country': 'US',
#   'usd pledged': 7522.0,
#   'usd_pledged_real': 7522.0},
#  {'_id': 1195741430,
#   'name': 'Bring the BBBC home for Christmas (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-10-20',
#   'goal': 55000.0,
#   'launched': Timestamp('2014-09-25 17:04:11'),
#   'pledged': 1395.0,
#   'state': 'canceled',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 1395.0,
#   'usd_pledged_real': 1395.0},
#  {'_id': 2024072867,
#   'name': 'Black Lotus Empire-issue #1',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2012-09-23',
#   'goal': 2500.0,
#   'launched': Timestamp('2012-08-14 18:25:36'),
#   'pledged': 3905.51,
#   'state': 'successful',
#   'backers': 195,
#   'country': 'US',
#   'usd pledged': 3905.51,
#   'usd_pledged_real': 3905.51},
#  {'_id': 223758456,
#   'name': 'Toasty the Magic Fireplace',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-10-20',
#   'goal': 10000.0,
#   'launched': Timestamp('2017-09-20 18:04:19'),
#   'pledged': 33.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 33.0},
#  {'_id': 1594750207,
#   'name': 'Lake Forest Drone',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'USD',
#   'deadline': '2016-04-14',
#   'goal': 875.0,
#   'launched': Timestamp('2016-03-05 18:11:17'),
#   'pledged': 103.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 103.0,
#   'usd_pledged_real': 103.0},
#  {'_id': 726485587,
#   'name': 'The Meadow Project',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-02-20',
#   'goal': 20000.0,
#   'launched': Timestamp('2012-01-07 17:39:58'),
#   'pledged': 21635.0,
#   'state': 'successful',
#   'backers': 290,
#   'country': 'US',
#   'usd pledged': 21635.0,
#   'usd_pledged_real': 21635.0},
#  {'_id': 260647442,
#   'name': 'Clash in the Caucuses 2016',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-12-13',
#   'goal': 17500.0,
#   'launched': Timestamp('2016-10-14 02:44:13'),
#   'pledged': 682.0,
#   'state': 'failed',
#   'backers': 15,
#   'country': 'US',
#   'usd pledged': 86.0,
#   'usd_pledged_real': 682.0},
#  {'_id': 1043191090,
#   'name': 'Politics with Allies',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-04-25',
#   'goal': 20000.0,
#   'launched': Timestamp('2017-03-21 18:05:36'),
#   'pledged': 554.0,
#   'state': 'failed',
#   'backers': 23,
#   'country': 'US',
#   'usd pledged': 127.0,
#   'usd_pledged_real': 554.0},
#  {'_id': 395755489,
#   'name': 'Kawaii Heroes Soft Enamel Pins | Stickers | Commissions',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-12-03',
#   'goal': 800.0,
#   'launched': Timestamp('2017-11-03 19:38:21'),
#   'pledged': 23.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 23.0,
#   'usd_pledged_real': 23.0},
#  {'_id': 830800632,
#   'name': 'Martin Game Studios',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-11-01',
#   'goal': 5000.0,
#   'launched': Timestamp('2014-10-02 18:10:05'),
#   'pledged': 3.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 3.0,
#   'usd_pledged_real': 3.0},
#  {'_id': 2113778157,
#   'name': 'Air Basketball',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-12-08',
#   'goal': 1500.0,
#   'launched': Timestamp('2013-11-08 03:02:49'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 163783398,
#   'name': 'ZERUBA',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-02-24',
#   'goal': 1000.0,
#   'launched': Timestamp('2015-01-25 02:21:51'),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 2069080555,
#   'name': 'Crashpads and Paddles: A Rock climbing adventure by canoe',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'CAD',
#   'deadline': '2015-06-06',
#   'goal': 1500.0,
#   'launched': Timestamp('2015-05-05 20:37:22'),
#   'pledged': 80.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'CA',
#   'usd pledged': 65.7148416,
#   'usd_pledged_real': 65.02479070145492},
#  {'_id': 1224888533,
#   'name': 'Eating Up Easter - Finishing Funds',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-06-09',
#   'goal': 30000.0,
#   'launched': Timestamp('2017-05-10 16:22:26'),
#   'pledged': 35182.0,
#   'state': 'successful',
#   'backers': 249,
#   'country': 'US',
#   'usd pledged': 4215.0,
#   'usd_pledged_real': 35182.0},
#  {'_id': 1841566953,
#   'name': 'Clocks Cameras Computers & Murder:  What Else Can Go Wrong?',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-05-19',
#   'goal': 6000.0,
#   'launched': Timestamp('2015-04-19 20:03:18'),
#   'pledged': 900.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 900.0,
#   'usd_pledged_real': 900.0},
#  {'_id': 449615827,
#   'name': 'High Caliber Community (HC2); a place for veteran networking',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-12-19',
#   'goal': 75000.0,
#   'launched': Timestamp('2017-11-19 21:37:19'),
#   'pledged': 4196.0,
#   'state': 'failed',
#   'backers': 30,
#   'country': 'US',
#   'usd pledged': 1876.0,
#   'usd_pledged_real': 4196.0},
#  {'_id': 442102012,
#   'name': "Rudely Stamp'd Historical Impressions",
#   'category': 'Plays',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2017-12-26',
#   'goal': 6000.0,
#   'launched': Timestamp('2017-10-27 05:04:26'),
#   'pledged': 550.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 550.0},
#  {'_id': 1054276073,
#   'name': '(Teacher) Documentary, Jack teaches Buddhist Monks English',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-09-01',
#   'goal': 2390.0,
#   'launched': Timestamp('2016-07-28 16:34:56'),
#   'pledged': 2773.0,
#   'state': 'successful',
#   'backers': 43,
#   'country': 'US',
#   'usd pledged': 320.0,
#   'usd_pledged_real': 2773.0},
#  {'_id': 1292948737,
#   'name': 'Tarot eCards App: Tarot Reading App for mobile devices',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2014-01-13',
#   'goal': 12000.0,
#   'launched': Timestamp('2013-12-09 13:51:59'),
#   'pledged': 796.66,
#   'state': 'failed',
#   'backers': 29,
#   'country': 'US',
#   'usd pledged': 796.66,
#   'usd_pledged_real': 796.66},
#  {'_id': 2036356057,
#   'name': 'Sound is Revolution',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'GBP',
#   'deadline': '2017-05-23',
#   'goal': 50000.0,
#   'launched': Timestamp('2017-04-23 22:07:56'),
#   'pledged': 11.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 14.125019261389902},
#  {'_id': 56346579,
#   'name': 'City of the Shroud',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-05-06',
#   'goal': 14000.0,
#   'launched': Timestamp('2016-04-06 18:00:04'),
#   'pledged': 16239.0,
#   'state': 'successful',
#   'backers': 302,
#   'country': 'US',
#   'usd pledged': 16239.0,
#   'usd_pledged_real': 16239.0},
#  {'_id': 797794426,
#   'name': "Skunk Rider's first album",
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2015-05-16',
#   'goal': 500.0,
#   'launched': Timestamp('2015-05-01 17:31:59'),
#   'pledged': 1395.0,
#   'state': 'successful',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 1395.0,
#   'usd_pledged_real': 1395.0},
#  {'_id': 1086953170,
#   'name': "'Jamie and Friends' - Greeting Cards",
#   'category': 'Stationery',
#   'main_category': 'Crafts',
#   'currency': 'GBP',
#   'deadline': '2015-07-25',
#   'goal': 1000.0,
#   'launched': Timestamp('2015-06-25 18:58:28'),
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'GB',
#   'usd pledged': 31.478563800000003,
#   'usd_pledged_real': 31.15167751783433},
#  {'_id': 955493948,
#   'name': 'W.E.T West End Terminal: Outdoor Chair Show/Art Installation',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2011-06-20',
#   'goal': 8500.0,
#   'launched': Timestamp('2011-05-04 02:51:56'),
#   'pledged': 8644.0,
#   'state': 'successful',
#   'backers': 47,
#   'country': 'US',
#   'usd pledged': 8644.0,
#   'usd_pledged_real': 8644.0},
#  {'_id': 133917405,
#   'name': 'BrainScrambler',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2012-05-04',
#   'goal': 8000.0,
#   'launched': Timestamp('2012-04-04 21:26:16'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1702541310,
#   'name': 'Paint Ring',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-06-24',
#   'goal': 55000.0,
#   'launched': Timestamp('2017-05-15 19:52:07'),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 87518909,
#   'name': 'Just Rock Showcase and Songwriter Circle 2014 at the studio',
#   'category': 'Performance Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2013-12-31',
#   'goal': 1500.0,
#   'launched': Timestamp('2013-11-15 17:38:39'),
#   'pledged': 2180.0,
#   'state': 'successful',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 2180.0,
#   'usd_pledged_real': 2180.0},
#  {'_id': 1957326840,
#   'name': 'BRIGADE RETURNS!',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2013-06-15',
#   'goal': 17500.0,
#   'launched': Timestamp('2013-05-16 21:24:04'),
#   'pledged': 35343.0,
#   'state': 'successful',
#   'backers': 562,
#   'country': 'US',
#   'usd pledged': 35343.0,
#   'usd_pledged_real': 35343.0},
#  {'_id': 1593966557,
#   'name': 'Red Box Games Dwarves, and Goblins, and Orcs Oh MY!!',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-06-16',
#   'goal': 5000.0,
#   'launched': Timestamp('2013-05-19 21:49:38'),
#   'pledged': 39258.0,
#   'state': 'successful',
#   'backers': 269,
#   'country': 'US',
#   'usd pledged': 39258.0,
#   'usd_pledged_real': 39258.0},
#  {'_id': 1029624752,
#   'name': 'Doodle Art to Color Returns!',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2014-06-29',
#   'goal': 25.0,
#   'launched': Timestamp('2014-06-14 18:50:10'),
#   'pledged': 25.5,
#   'state': 'successful',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 25.5,
#   'usd_pledged_real': 25.5},
#  {'_id': 888065158,
#   'name': 'New Patent Design Pocket Sheet+',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-08-17',
#   'goal': 25000.0,
#   'launched': Timestamp('2015-06-18 23:21:20'),
#   'pledged': 190.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 190.0,
#   'usd_pledged_real': 190.0},
#  {'_id': 14239768,
#   'name': 'What I Did Today',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-09-17',
#   'goal': 5000.0,
#   'launched': Timestamp('2012-08-16 00:00:27'),
#   'pledged': 360.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 360.0,
#   'usd_pledged_real': 360.0},
#  {'_id': 1890385189,
#   'name': 'The Falling Girl- Chronicles of the Closed World, Book 1',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2012-04-09',
#   'goal': 500.0,
#   'launched': Timestamp('2012-03-10 01:37:26'),
#   'pledged': 695.0,
#   'state': 'successful',
#   'backers': 9,
#   'country': 'US',
#   'usd pledged': 695.0,
#   'usd_pledged_real': 695.0},
#  {'_id': 368889340,
#   'name': '"Intermittent Polarity" Art book by Brent and Kayla Woodside',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2012-08-12',
#   'goal': 1000.0,
#   'launched': Timestamp('2012-07-13 03:32:53'),
#   'pledged': 610.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'US',
#   'usd pledged': 610.0,
#   'usd_pledged_real': 610.0},
#  {'_id': 671724371,
#   'name': 'The Dark Lord and the Seamstress',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'CAD',
#   'deadline': '2014-09-14',
#   'goal': 5000.0,
#   'launched': Timestamp('2014-08-11 21:02:05'),
#   'pledged': 5336.0,
#   'state': 'successful',
#   'backers': 99,
#   'country': 'CA',
#   'usd pledged': 4862.92048512,
#   'usd_pledged_real': 4860.630351612315},
#  {'_id': 231038205,
#   'name': "Towering Trees' First Album!",
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-08-11',
#   'goal': 2250.0,
#   'launched': Timestamp('2013-07-12 21:23:16'),
#   'pledged': 2267.0,
#   'state': 'successful',
#   'backers': 66,
#   'country': 'US',
#   'usd pledged': 2267.0,
#   'usd_pledged_real': 2267.0},
#  {'_id': 673468258,
#   'name': 'Daybook notebooks (Canceled)',
#   'category': 'Stationery',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2016-02-25',
#   'goal': 1000.0,
#   'launched': Timestamp('2016-01-26 06:29:43'),
#   'pledged': 52.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 52.0,
#   'usd_pledged_real': 52.0},
#  {'_id': 765608919,
#   'name': 'Big Barbeque',
#   'category': 'Events',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-10-04',
#   'goal': 20000.0,
#   'launched': Timestamp('2014-09-04 15:25:21'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1451163055,
#   'name': 'iKlimt App: The Life & Work of Gustav Klimt',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2012-02-11',
#   'goal': 5000.0,
#   'launched': Timestamp('2012-01-12 07:17:54'),
#   'pledged': 66.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 66.0,
#   'usd_pledged_real': 66.0},
#  {'_id': 523925424,
#   'name': 'Seasons in the Sanctuary',
#   'category': 'Graphic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-10-02',
#   'goal': 4000.0,
#   'launched': Timestamp('2012-09-07 21:56:47'),
#   'pledged': 4808.0,
#   'state': 'successful',
#   'backers': 101,
#   'country': 'US',
#   'usd pledged': 4808.0,
#   'usd_pledged_real': 4808.0},
#  {'_id': 488491938,
#   'name': 'Charlie Chipmink',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-06-03',
#   'goal': 35000.0,
#   'launched': Timestamp('2017-05-04 02:14:23'),
#   'pledged': 430.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 430.0},
#  {'_id': 899938474,
#   'name': '500 Years Later: An Oral History of Final Fantasy VII',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'GBP',
#   'deadline': '2017-12-10',
#   'goal': 38000.0,
#   'launched': Timestamp('2017-11-10 14:00:05'),
#   'pledged': 72881.0,
#   'state': 'successful',
#   'backers': 1871,
#   'country': 'GB',
#   'usd pledged': 52551.44488998,
#   'usd_pledged_real': 97495.75267882225},
#  {'_id': 2146928537,
#   'name': 'Crimson Apple, Debut Album "Hello"',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2015-08-27',
#   'goal': 8000.0,
#   'launched': Timestamp('2015-07-27 13:53:12'),
#   'pledged': 8805.0,
#   'state': 'undefined',
#   'backers': 0,
#   'country': 'N,0"',
#   'usd pledged': nan,
#   'usd_pledged_real': 8805.0},
#  {'_id': 870077018,
#   'name': 'Take every shower with Matt Gator and stop shower mat mold',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-06-08',
#   'goal': 34000.0,
#   'launched': Timestamp('2017-05-10 07:49:12'),
#   'pledged': 21.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 21.0},
#  {'_id': 1564568013,
#   'name': 'The VDown Podcast Intro (Canceled)',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-10-03',
#   'goal': 1100.0,
#   'launched': Timestamp('2014-09-03 01:45:25'),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1010701682,
#   'name': 'XPLUS Watches: Second Release',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'AUD',
#   'deadline': '2015-10-29',
#   'goal': 10000.0,
#   'launched': Timestamp('2015-09-30 00:56:12'),
#   'pledged': 16889.0,
#   'state': 'successful',
#   'backers': 114,
#   'country': 'AU',
#   'usd pledged': 11874.69592693,
#   'usd_pledged_real': 11970.37352044794},
#  {'_id': 1425142887,
#   'name': 'Mathatar - An online Maths adventure game for KS2 to GCSE',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2017-01-12',
#   'goal': 5000.0,
#   'launched': Timestamp('2016-12-07 18:21:50'),
#   'pledged': 369.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'GB',
#   'usd pledged': 154.21025895,
#   'usd_pledged_real': 449.34242571846085},
#  {'_id': 1843557102,
#   'name': 'Son of a Gun',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-02-26',
#   'goal': 20000.0,
#   'launched': Timestamp('2011-12-28 17:57:05'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1721659818,
#   'name': 'Bourbon Chicken',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'CAD',
#   'deadline': '2014-08-05',
#   'goal': 30.0,
#   'launched': Timestamp('2014-07-21 20:36:34'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 186346662,
#   'name': 'T-Shirt of the Year',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2011-07-03',
#   'goal': 1700.0,
#   'launched': Timestamp('2011-04-04 06:35:03'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 619587010,
#   'name': 'Nobody: A Fallout Tale',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-12-11',
#   'goal': 8200.0,
#   'launched': Timestamp('2015-11-10 22:37:04'),
#   'pledged': 1229.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 1229.0,
#   'usd_pledged_real': 1229.0},
#  {'_id': 831196575,
#   'name': 'The Tower',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2015-08-01',
#   'goal': 50000.0,
#   'launched': Timestamp('2015-06-22 17:51:49'),
#   'pledged': 283.0,
#   'state': 'failed',
#   'backers': 23,
#   'country': 'GB',
#   'usd pledged': 449.38753223,
#   'usd_pledged_real': 439.1273314092417},
#  {'_id': 1517578386,
#   'name': 'AutoDock Car Organizer',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-10-16',
#   'goal': 50000.0,
#   'launched': Timestamp('2017-09-01 15:31:27'),
#   'pledged': 1775.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1775.0},
#  {'_id': 569529453,
#   'name': 'Let Me Tell You/No Money Down David Pemberton/Sally Phillips',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-09-30',
#   'goal': 10000.0,
#   'launched': Timestamp('2015-08-31 23:19:47'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 639226845,
#   'name': 'Kiss Kiss Missiles',
#   'category': 'Performance Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2012-03-08',
#   'goal': 4000.0,
#   'launched': Timestamp('2012-02-03 00:35:06'),
#   'pledged': 4075.0,
#   'state': 'successful',
#   'backers': 76,
#   'country': 'US',
#   'usd pledged': 4075.0,
#   'usd_pledged_real': 4075.0},
#  {'_id': 2072974553,
#   'name': 'The Fountain of Light: a luminous juggling machine',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2011-05-20',
#   'goal': 8000.0,
#   'launched': Timestamp('2011-04-03 05:55:28'),
#   'pledged': 8295.36,
#   'state': 'successful',
#   'backers': 124,
#   'country': 'US',
#   'usd pledged': 8295.36,
#   'usd_pledged_real': 8295.36},
#  {'_id': 328543359,
#   'name': 'Dead of Winter',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-12-10',
#   'goal': 700.0,
#   'launched': Timestamp('2017-11-22 18:00:03'),
#   'pledged': 767.0,
#   'state': 'successful',
#   'backers': 23,
#   'country': 'US',
#   'usd pledged': 226.0,
#   'usd_pledged_real': 767.0},
#  {'_id': 893780456,
#   'name': 'To Nowhere From Nobody: An Open Source Music Project',
#   'category': 'Pop',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2012-11-09',
#   'goal': 2500.0,
#   'launched': Timestamp('2012-10-20 15:14:49'),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 1771281327,
#   'name': 'Swiss Producer Battle (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'CHF',
#   'deadline': '2015-08-16',
#   'goal': 20000.0,
#   'launched': Timestamp('2015-07-10 20:55:47'),
#   'pledged': 175.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'CH',
#   'usd pledged': 185.09312849999998,
#   'usd_pledged_real': 183.3881751304676},
#  {'_id': 1840068470,
#   'name': 'Diamond by Stay high clothing',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'AUD',
#   'deadline': '2016-08-01',
#   'goal': 2000.0,
#   'launched': Timestamp('2016-07-11 17:28:19'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'AU',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 933275417,
#   'name': 'Fruition of FORMS OF IDENTIFICATION',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2010-12-16',
#   'goal': 2000.0,
#   'launched': Timestamp('2010-10-15 00:16:02'),
#   'pledged': 2196.0,
#   'state': 'successful',
#   'backers': 44,
#   'country': 'US',
#   'usd pledged': 2196.0,
#   'usd_pledged_real': 2196.0},
#  {'_id': 1612333257,
#   'name': 'CUSTOM PET PORTRAIT IN 3 STYLES ( Cat / Dog / all animals! )',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'HKD',
#   'deadline': '2017-04-14',
#   'goal': 800.0,
#   'launched': Timestamp('2017-03-15 03:59:16'),
#   'pledged': 1250.0,
#   'state': 'successful',
#   'backers': 3,
#   'country': 'HK',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 160.74689437000075},
#  {'_id': 350352717,
#   'name': '"The \'Devil" (Canceled)',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-03-10',
#   'goal': 600.0,
#   'launched': Timestamp('2013-02-07 19:08:20'),
#   'pledged': 320.0,
#   'state': 'canceled',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'_id': 358910116,
#   'name': 'Piano Wars: Dueling Piano Competition - TV Pilot Episode',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2011-06-21',
#   'goal': 12500.0,
#   'launched': Timestamp('2011-04-22 03:01:34'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1509749942,
#   'name': 'Clash Calc (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-08-10',
#   'goal': 200.0,
#   'launched': Timestamp('2015-07-20 19:05:57'),
#   'pledged': 10.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 256728964,
#   'name': '"Film School Porno" My film school senior project',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2010-10-01',
#   'goal': 2000.0,
#   'launched': Timestamp('2010-08-17 00:59:19'),
#   'pledged': 2038.0,
#   'state': 'successful',
#   'backers': 12,
#   'country': 'US',
#   'usd pledged': 2038.0,
#   'usd_pledged_real': 2038.0},
#  {'_id': 640450615,
#   'name': 'Carry the Tune',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-04-13',
#   'goal': 6000.0,
#   'launched': Timestamp('2014-03-14 04:43:39'),
#   'pledged': 6756.0,
#   'state': 'successful',
#   'backers': 127,
#   'country': 'US',
#   'usd pledged': 6756.0,
#   'usd_pledged_real': 6756.0},
#  {'_id': 7168821,
#   'name': 'FitCraft',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-05-01',
#   'goal': 5000.0,
#   'launched': Timestamp('2015-03-02 23:00:51'),
#   'pledged': 1504.0,
#   'state': 'failed',
#   'backers': 71,
#   'country': 'US',
#   'usd pledged': 1504.0,
#   'usd_pledged_real': 1504.0},
#  {'_id': 727551984,
#   'name': 'Robert Rex Waller Jr "Fancy Free" Solo Covers LP (Pre-Order)',
#   'category': 'Country & Folk',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2016-04-23',
#   'goal': 7000.0,
#   'launched': Timestamp('2016-03-22 18:46:14'),
#   'pledged': 9244.0,
#   'state': 'successful',
#   'backers': 151,
#   'country': 'US',
#   'usd pledged': 9244.0,
#   'usd_pledged_real': 9244.0},
#  {'_id': 757625439,
#   'name': 'SeaGulls',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-06-01',
#   'goal': 8000.0,
#   'launched': Timestamp('2015-05-02 22:42:38'),
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 2012699952,
#   'name': 'iCROS - microscope for your smartphone, tablet or iPod touch',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'CHF',
#   'deadline': '2016-11-20',
#   'goal': 20000.0,
#   'launched': Timestamp('2016-10-18 06:20:52'),
#   'pledged': 4293.0,
#   'state': 'failed',
#   'backers': 268,
#   'country': 'CH',
#   'usd pledged': 1501.75625937,
#   'usd_pledged_real': 4235.398579321231},
#  {'_id': 1185745802,
#   'name': 'The Microbrew Project',
#   'category': 'Events',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-10-26',
#   'goal': 15000.0,
#   'launched': Timestamp('2014-08-27 18:40:21'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1770997012,
#   'name': 'So you want to be an entreprenuer',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-11-28',
#   'goal': 1000.0,
# ...
#  {'_id': 1361712743,
#   'name': "A set of 4 bumper stickers to save America's infrastructure",
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-02-24',
#   'goal': 140.0,
#   'launched': Timestamp('2016-01-25 20:50:47'),
#   'pledged': 96.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 96.0,
#   'usd_pledged_real': 96.0},
#  {'_id': 478602668,
#   'name': 'NoHo Fringe Festival performance - #Right2Recess',
#   'category': 'Festivals',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2017-12-03',
#   'goal': 3000.0,
#   'launched': Timestamp('2017-11-03 20:51:42'),
#   'pledged': 540.0,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 540.0},
#  {'_id': 189295089,
#   'name': 'A MAN NAMED MAGICK: A Short Documentary About A Professional Magician',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2010-10-27',
#   'goal': 5000.0,
#   'launched': Timestamp('2010-09-27 20:51:47'),
#   'pledged': 5161.0,
#   'state': 'successful',
#   'backers': 79,
#   'country': 'US',
#   'usd pledged': 5161.0,
#   'usd_pledged_real': 5161.0},
#  {'_id': 887319573,
#   'name': 'PhiLOCK (Canceled)',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-12-07',
#   'goal': 100000.0,
#   'launched': Timestamp('2015-10-28 13:56:59'),
#   'pledged': 2532.0,
#   'state': 'canceled',
#   'backers': 34,
#   'country': 'US',
#   'usd pledged': 2532.0,
#   'usd_pledged_real': 2532.0},
#  {'_id': 827535157,
#   'name': 'Cravar ï¿½ Leather Tote Bags (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-11-22',
#   'goal': 15000.0,
#   'launched': Timestamp('2015-10-23 16:33:13'),
#   'pledged': 6748.0,
#   'state': 'canceled',
#   'backers': 35,
#   'country': 'US',
#   'usd pledged': 6748.0,
#   'usd_pledged_real': 6748.0},
#  {'_id': 1169744690,
#   'name': 'Camper Enamel Pin',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-09-26',
#   'goal': 350.0,
#   'launched': Timestamp('2017-09-11 17:57:41'),
#   'pledged': 379.0,
#   'state': 'successful',
#   'backers': 21,
#   'country': 'US',
#   'usd pledged': 55.0,
#   'usd_pledged_real': 379.0},
#  {'_id': 634066630,
#   'name': "Plug 'N Plunge (Bathtub Overflow Pipe Plug)",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-04-01',
#   'goal': 2500.0,
#   'launched': Timestamp('2015-02-02 21:15:46'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 575660043,
#   'name': 'CANCELED (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-09-12',
#   'goal': 33000.0,
#   'launched': Timestamp('2014-08-10 19:42:03'),
#   'pledged': 3649.0,
#   'state': 'canceled',
#   'backers': 17,
#   'country': 'US',
#   'usd pledged': 3649.0,
#   'usd_pledged_real': 3649.0},
#  {'_id': 2067634614,
#   'name': 'Changing the Radio / Production Industry with an iOS Device',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'GBP',
#   'deadline': '2012-12-21',
#   'goal': 500.0,
#   'launched': Timestamp('2012-11-21 01:18:53'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1707385269,
#   'name': 'Better Food Control - Less Food Poisoning',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'NOK',
#   'deadline': '2017-04-18',
#   'goal': 200000.0,
#   'launched': Timestamp('2017-02-17 23:25:04'),
#   'pledged': 705.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'NO',
#   'usd pledged': 84.043491,
#   'usd_pledged_real': 81.55568923233541},
#  {'_id': 1613602272,
#   'name': 'ROPIX JUMP ROPE SHOES',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-03-30',
#   'goal': 10000.0,
#   'launched': Timestamp('2014-02-05 05:36:38'),
#   'pledged': 10690.0,
#   'state': 'successful',
#   'backers': 117,
#   'country': 'US',
#   'usd pledged': 10690.0,
#   'usd_pledged_real': 10690.0},
#  {'_id': 1109297992,
#   'name': 'Symphony of 1000: Be a part of it!',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-01-23',
#   'goal': 4000.0,
#   'launched': Timestamp('2013-12-24 21:40:33'),
#   'pledged': 162.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 162.0,
#   'usd_pledged_real': 162.0},
#  {'_id': 142828580,
#   'name': 'THE POWER PRINCIPLE',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2012-08-24',
#   'goal': 7000.0,
#   'launched': Timestamp('2012-07-10 12:37:25'),
#   'pledged': 7263.0,
#   'state': 'successful',
#   'backers': 189,
#   'country': 'US',
#   'usd pledged': 7263.0,
#   'usd_pledged_real': 7263.0},
#  {'_id': 1109543634,
#   'name': "'AlwaysOn' 5pee (for scale)",
#   'category': 'Fine Art',
#   'main_category': 'Photography',
#   'currency': 'GBP',
#   'deadline': '2014-11-05',
#   'goal': 200.0,
#   'launched': Timestamp('2014-09-06 01:24:05'),
#   'pledged': 4.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'GB',
#   'usd pledged': 6.58338684,
#   'usd_pledged_real': 6.327812317086678},
#  {'_id': 1434110341,
#   'name': 'The Prettiest Panties in the World (Canceled)',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-01-11',
#   'goal': 30000.0,
#   'launched': Timestamp('2015-12-01 18:00:24'),
#   'pledged': 427.0,
#   'state': 'canceled',
#   'backers': 9,
#   'country': 'US',
#   'usd pledged': 427.0,
#   'usd_pledged_real': 427.0},
#  {'_id': 48806525,
#   'name': 'Coffee Crisis for the Sega Genesis - Metal, Aliens & Awesome',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-12-04',
#   'goal': 10000.0,
#   'launched': Timestamp('2016-11-04 21:22:22'),
#   'pledged': 15076.0,
#   'state': 'successful',
#   'backers': 213,
#   'country': 'US',
#   'usd pledged': 1917.0,
#   'usd_pledged_real': 15076.0},
#  {'_id': 1439048120,
#   'name': 'The Black Operator',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2013-07-12',
#   'goal': 3300.0,
#   'launched': Timestamp('2013-06-12 03:05:30'),
#   'pledged': 1134.0,
#   'state': 'failed',
#   'backers': 32,
#   'country': 'US',
#   'usd pledged': 1134.0,
#   'usd_pledged_real': 1134.0},
#  {'_id': 1300265365,
#   'name': 'The Athlete Spot: We Have The Ingredients For Your Success',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2018-01-09',
#   'goal': 50000.0,
#   'launched': Timestamp('2017-11-10 03:59:11'),
#   'pledged': 0.0,
#   'state': 'live',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 513123115,
#   'name': "Kaila Gieser's debut EP!",
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-05-10',
#   'goal': 1500.0,
#   'launched': Timestamp('2013-04-08 19:15:48'),
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 1506474844,
#   'name': "The Revolution's Bride",
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-07-02',
#   'goal': 15000.0,
#   'launched': Timestamp('2016-06-04 19:59:25'),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 1252795414,
#   'name': 'EZC Smartlight "The Smarter Way To Ride"',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2016-04-12',
#   'goal': 400.0,
#   'launched': Timestamp('2016-03-08 13:26:58'),
#   'pledged': 1595.0,
#   'state': 'successful',
#   'backers': 22,
#   'country': 'CA',
#   'usd pledged': 1195.5930195,
#   'usd_pledged_real': 1238.2578992314259},
#  {'_id': 1721170633,
#   'name': 'LINJA shoes - The Finest Comfortable High Heels',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-09-22',
#   'goal': 25000.0,
#   'launched': Timestamp('2016-09-06 12:32:38'),
#   'pledged': 19410.0,
#   'state': 'failed',
#   'backers': 112,
#   'country': 'NL',
#   'usd pledged': 4733.727817600001,
#   'usd_pledged_real': 21766.434162424022},
#  {'_id': 666068495,
#   'name': '360ï¿½ India',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'GBP',
#   'deadline': '2015-08-01',
#   'goal': 700.0,
#   'launched': Timestamp('2015-07-22 11:40:00'),
#   'pledged': 16.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'GB',
#   'usd pledged': 24.9036152,
#   'usd_pledged_real': 24.826986934798125},
#  {'_id': 1884096172,
#   'name': 'The Wing Commander Orchestral Project Volume 2, Phase 1!',
#   'category': 'Jazz',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-08-26',
#   'goal': 15000.0,
#   'launched': Timestamp('2017-07-27 21:58:33'),
#   'pledged': 16552.0,
#   'state': 'successful',
#   'backers': 275,
#   'country': 'US',
#   'usd pledged': 5130.0,
#   'usd_pledged_real': 16552.0},
#  {'_id': 358516752,
#   'name': 'My YouTube Band Project',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2012-07-10',
#   'goal': 35000.0,
#   'launched': Timestamp('2012-06-09 23:58:18'),
#   'pledged': 79937.33,
#   'state': 'successful',
#   'backers': 680,
#   'country': 'US',
#   'usd pledged': 79937.33,
#   'usd_pledged_real': 79937.33},
#  {'_id': 1658564725,
#   'name': 'Help Fund a \'Miraculous\'  new Musical, "Miracolo"',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2013-10-24',
#   'goal': 18000.0,
#   'launched': Timestamp('2013-09-14 17:41:56'),
#   'pledged': 18000.0,
#   'state': 'successful',
#   'backers': 51,
#   'country': 'US',
#   'usd pledged': 18000.0,
#   'usd_pledged_real': 18000.0},
#  {'_id': 2071301174,
#   'name': 'Wallets Refined & Redefined - by Obtainium',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-01-07',
#   'goal': 25000.0,
#   'launched': Timestamp('2012-11-23 14:59:13'),
#   'pledged': 88867.0,
#   'state': 'successful',
#   'backers': 715,
#   'country': 'US',
#   'usd pledged': 88867.0,
#   'usd_pledged_real': 88867.0},
#  {'_id': 2055734097,
#   'name': 'Powermitten: EPIC performance and Album Mastering (Canceled)',
#   'category': 'Electronic Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2011-05-04',
#   'goal': 1100.0,
#   'launched': Timestamp('2011-04-22 08:39:10'),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 252240271,
#   'name': 'Best Man Competition Webseries',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-03',
#   'goal': 9500.0,
#   'launched': Timestamp('2013-07-03 20:35:13'),
#   'pledged': 377.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 377.0,
#   'usd_pledged_real': 377.0},
#  {'_id': 12976470,
#   'name': 'Love Collection',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2013-02-28',
#   'goal': 5000.0,
#   'launched': Timestamp('2013-01-29 04:45:19'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 581166953,
#   'name': 'Pay my rent, dance a jig!',
#   'category': 'Dance',
#   'main_category': 'Dance',
#   'currency': 'AUD',
#   'deadline': '2014-08-09',
#   'goal': 3000.0,
#   'launched': Timestamp('2014-07-10 01:19:48'),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'AU',
#   'usd pledged': 0.93876087,
#   'usd_pledged_real': 0.9321401938851605},
#  {'_id': 1780435209,
#   'name': 'The Holophonics Record a New Ska Cover Album',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-09-28',
#   'goal': 2000.0,
#   'launched': Timestamp('2013-08-29 19:07:17'),
#   'pledged': 2899.5,
#   'state': 'successful',
#   'backers': 51,
#   'country': 'US',
#   'usd pledged': 2899.5,
#   'usd_pledged_real': 2899.5},
#  {'_id': 2057158348,
#   'name': 'BubblePhoneCaseï¿½, Top anti-hacking phone case system.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-12-06',
#   'goal': 10000.0,
#   'launched': Timestamp('2016-10-31 15:19:14'),
#   'pledged': 349.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'ES',
#   'usd pledged': 383.49541128,
#   'usd_pledged_real': 368.5088589952062},
#  {'_id': 93529012,
#   'name': 'Hamtramck Labor Day Festival',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2012-07-19',
#   'goal': 20000.0,
#   'launched': Timestamp('2012-06-19 18:04:53'),
#   'pledged': 2366.0,
#   'state': 'failed',
#   'backers': 44,
#   'country': 'US',
#   'usd pledged': 2366.0,
#   'usd_pledged_real': 2366.0},
#  {'_id': 1551300378,
#   'name': 'Crab Cakes',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-01-01',
#   'goal': 3000.0,
#   'launched': Timestamp('2012-11-02 18:46:42'),
#   'pledged': 775.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 775.0,
#   'usd_pledged_real': 775.0},
#  {'_id': 819881112,
#   'name': 'Excellent "Made in Italy" leather shoes for man/woman',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-12-18',
#   'goal': 178250.0,
#   'launched': Timestamp('2016-11-16 18:18:47'),
#   'pledged': 765.0,
#   'state': 'failed',
#   'backers': 19,
#   'country': 'IT',
#   'usd pledged': 344.0120416000001,
#   'usd_pledged_real': 799.1225321215919},
#  {'_id': 1776712156,
#   'name': 'Twig the Fairy and the Fairly Short Fairy Tales',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-12-13',
#   'goal': 17000.0,
#   'launched': Timestamp('2015-11-21 02:06:15'),
#   'pledged': 25410.0,
#   'state': 'successful',
#   'backers': 315,
#   'country': 'US',
#   'usd pledged': 25410.0,
#   'usd_pledged_real': 25410.0},
#  {'_id': 255401982,
#   'name': 'Civil Architect',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2014-12-20',
#   'goal': 100000.0,
#   'launched': Timestamp('2014-11-20 22:00:13'),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 750725377,
#   'name': 'GHETTO CHRONICLES The Musical Comedy Stage Play (Canceled)',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2011-09-04',
#   'goal': 10000.0,
#   'launched': Timestamp('2011-07-21 08:13:42'),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 147428325,
#   'name': 'Flyy Magazine',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2012-02-17',
#   'goal': 10000.0,
#   'launched': Timestamp('2012-01-18 03:55:27'),
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'_id': 400288569,
#   'name': 'Dracucat : A vampire kitten card game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-10-29',
#   'goal': 1900.0,
#   'launched': Timestamp('2015-09-29 07:04:08'),
#   'pledged': 2944.0,
#   'state': 'successful',
#   'backers': 129,
#   'country': 'FR',
#   'usd pledged': 3295.37237632,
#   'usd_pledged_real': 3243.3980764357875},
#  {'_id': 1050943303,
#   'name': "Little Baby's Ice Cream Funds for Responsible Packaging",
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2012-07-10',
#   'goal': 5952.0,
#   'launched': Timestamp('2012-06-15 06:03:09'),
#   'pledged': 6314.0,
#   'state': 'successful',
#   'backers': 151,
#   'country': 'US',
#   'usd pledged': 6314.0,
#   'usd_pledged_real': 6314.0},
#  ...]

# %% [markdown]
# ## Question 1

# %%
cur = collection.find().sort([("usd_pledged_real",-1)]).limit(5)
list(cur)
# Out:
# [{'_id': 342886736,
#   'name': "COOLEST COOLER: 21st Century Cooler that's Actually Cooler",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-08-30',
#   'goal': '50000.0',
#   'launched': datetime.datetime(2014, 7, 8, 10, 14, 37),
#   'pledged': '13285226.36',
#   'state': 'successful',
#   'backers': '62642',
#   'country': 'US',
#   'usd pledged': '13285226.36',
#   'usd_pledged_real': 13285226.36},
#  {'_id': 2103598555,
#   'name': 'Pebble 2, Time 2 + All-New Pebble Core',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-06-30',
#   'goal': '1000000.0',
#   'launched': datetime.datetime(2016, 5, 24, 15, 49, 52),
#   'pledged': '12779843.49',
#   'state': 'successful',
#   'backers': '66673',
#   'country': 'US',
#   'usd pledged': '12779843.49',
#   'usd_pledged_real': 12779843.49},
#  {'_id': 1033978702,
#   'name': 'OUYA: A New Kind of Video Game Console',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-08-09',
#   'goal': '950000.0',
#   'launched': datetime.datetime(2012, 7, 10, 14, 44, 41),
#   'pledged': '8596474.58',
#   'state': 'successful',
#   'backers': '63416',
#   'country': 'US',
#   'usd pledged': '8596474.58',
#   'usd_pledged_real': 8596474.58},
#  {'_id': 450099426,
#   'name': 'The Everyday Backpack, Tote, and Sling',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-09-10',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2016, 7, 13, 0, 47, 35),
#   'pledged': 6565782.5,
#   'state': 'successful',
#   'backers': 26359,
#   'country': 'US',
#   'usd pledged': 1462611.0,
#   'usd_pledged_real': 6565782.5},
#  {'_id': 1386523707,
#   'name': 'Fidget Cube: A Vinyl Desk Toy',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-10-20',
#   'goal': '15000.0',
#   'launched': datetime.datetime(2016, 8, 30, 22, 2, 9),
#   'pledged': '6465690.3',
#   'state': 'successful',
#   'backers': '154926',
#   'country': 'US',
#   'usd pledged': '13770.0',
#   'usd_pledged_real': 6465690.3}]

# %% [markdown]
# ## Question 2

# %%
cur = collection.find({"usd_pledged_real":{"$gte":"goal"}})
list(cur)
# Out:
# []

# %% [markdown]
# ## Question 3

# %%
cur = collection.aggregate([{"$group" : {"_id" : "$category", "nombre" : {"$sum" : 1}}}])
list(cur)
# Out:
# [{'_id': 'Rock', 'nombre': 2707},
#  {'_id': 'Comics', 'nombre': 1931},
#  {'_id': 'Anthologies', 'nombre': 300},
#  {'_id': 'Comedy', 'nombre': 923},
#  {'_id': 'Textiles', 'nombre': 105},
#  {'_id': 'Dance', 'nombre': 901},
#  {'_id': 'Farms', 'nombre': 482},
#  {'_id': 'Narrative Film', 'nombre': 2099},
#  {'_id': 'Vegan', 'nombre': 229},
#  {'_id': 'Radio & Podcasts', 'nombre': 349},
#  {'_id': 'Immersive', 'nombre': 131},
#  {'_id': 'Gaming Hardware', 'nombre': 178},
#  {'_id': 'Food Trucks', 'nombre': 687},
#  {'_id': 'Jewelry', 'nombre': 472},
#  {'_id': 'Puzzles', 'nombre': 95},
#  {'_id': 'Chiptune', 'nombre': 10},
#  {'_id': 'Television', 'nombre': 401},
#  {'_id': 'Comic Books', 'nombre': 1032},
#  {'_id': 'Ceramics', 'nombre': 128},
#  {'_id': 'Nonfiction', 'nombre': 3390},
#  {'_id': 'Community Gardens', 'nombre': 115},
#  {'_id': 'Games', 'nombre': 1331},
#  {'_id': 'Photobooks', 'nombre': 608},
#  {'_id': 'Punk', 'nombre': 127},
#  {'_id': 'Zines', 'nombre': 144},
#  {'_id': 'Quilts', 'nombre': 32},
#  {'_id': 'Hardware', 'nombre': 1431},
#  {'_id': 'Food', 'nombre': 4612},
#  {'_id': 'Public Art', 'nombre': 1248},
#  {'_id': 'Fabrication Tools', 'nombre': 96},
#  {'_id': '3D Printing', 'nombre': 271},
#  {'_id': 'R&B', 'nombre': 172},
#  {'_id': 'Makerspaces', 'nombre': 91},
#  {'_id': 'Events', 'nombre': 322},
#  {'_id': 'Publishing', 'nombre': 2332},
#  {'_id': 'Young Adult', 'nombre': 328},
#  {'_id': 'Fashion', 'nombre': 3379},
#  {'_id': 'Thrillers', 'nombre': 302},
#  {'_id': 'Romance', 'nombre': 74},
#  {'_id': 'Product Design', 'nombre': 8886},
#  {'_id': 'Classical Music', 'nombre': 1064},
#  {'_id': 'Graphic Design', 'nombre': 765},
#  {'_id': 'Academic', 'nombre': 367},
#  {'_id': 'Country & Folk', 'nombre': 1790},
#  {'_id': 'Video Art', 'nombre': 65},
#  {'_id': 'Letterpress', 'nombre': 24},
#  {'_id': 'Art', 'nombre': 3358},
#  {'_id': 'Pop', 'nombre': 1302},
#  {'_id': 'Action', 'nombre': 282},
#  {'_id': 'Flight', 'nombre': 158},
#  {'_id': 'Illustration', 'nombre': 1263},
#  {'_id': 'Interactive Design', 'nombre': 146},
#  {'_id': 'Printing', 'nombre': 83},
#  {'_id': 'Drinks', 'nombre': 995},
#  {'_id': 'Nature', 'nombre': 219},
#  {'_id': 'Movie Theaters', 'nombre': 90},
#  {'_id': 'Musical', 'nombre': 367},
#  {'_id': 'Fantasy', 'nombre': 132},
#  {'_id': 'Blues', 'nombre': 113},
#  {'_id': 'Translations', 'nombre': 76},
#  {'_id': 'Workshops', 'nombre': 59},
#  {'_id': 'Theater', 'nombre': 2786},
#  {'_id': 'Video Games', 'nombre': 4799},
#  {'_id': 'Family', 'nombre': 130},
#  {'_id': 'Wearables', 'nombre': 508},
#  {'_id': 'Accessories', 'nombre': 1204},
#  {'_id': 'Apps', 'nombre': 2535},
#  {'_id': 'Places', 'nombre': 283},
#  {'_id': 'Space Exploration', 'nombre': 137},
#  {'_id': 'Drama', 'nombre': 871},
#  {'_id': 'Technology', 'nombre': 2690},
#  {'_id': 'Graphic Novels', 'nombre': 702},
#  {'_id': 'Animation', 'nombre': 1017},
#  {'_id': 'Live Games', 'nombre': 394},
#  {'_id': 'Calendars', 'nombre': 112},
#  {'_id': 'Jazz', 'nombre': 733},
#  {'_id': 'Faith', 'nombre': 439},
#  {'_id': 'Performance Art', 'nombre': 855},
#  {'_id': 'Documentary', 'nombre': 6498},
#  {'_id': 'Photo', 'nombre': 58},
#  {'_id': 'Robots', 'nombre': 237},
#  {'_id': 'Mobile Games', 'nombre': 650},
#  {'_id': 'Glass', 'nombre': 51},
#  {'_id': 'Playing Cards', 'nombre': 963},
#  {'_id': 'Video', 'nombre': 147},
#  {'_id': 'Residencies', 'nombre': 32},
#  {'_id': 'Science Fiction', 'nombre': 274},
#  {'_id': "Children's Books", 'nombre': 2686},
#  {'_id': 'Painting', 'nombre': 1288},
#  {'_id': 'Metal', 'nombre': 274},
#  {'_id': 'Film & Video', 'nombre': 4003},
#  {'_id': 'Camera Equipment', 'nombre': 165},
#  {'_id': 'Architecture', 'nombre': 300},
#  {'_id': 'Typography', 'nombre': 44},
#  {'_id': 'Latin', 'nombre': 63},
#  {'_id': 'Crochet', 'nombre': 61},
#  {'_id': 'Literary Spaces', 'nombre': 10},
#  {'_id': 'DIY', 'nombre': 480},
#  {'_id': 'Footwear', 'nombre': 379},
#  {'_id': 'Stationery', 'nombre': 90},
#  {'_id': 'DIY Electronics', 'nombre': 358},
#  {'_id': 'Sculpture', 'nombre': 737},
#  {'_id': 'Music Videos', 'nombre': 299},
#  {'_id': 'Mixed Media', 'nombre': 1118},
#  {'_id': 'Childrenswear', 'nombre': 192},
#  {'_id': 'Pottery', 'nombre': 40},
#  {'_id': 'Taxidermy', 'nombre': 7},
#  {'_id': 'Crafts', 'nombre': 1834},
#  {'_id': 'Fine Art', 'nombre': 291},
#  {'_id': 'Hip-Hop', 'nombre': 1555},
#  {'_id': 'Webseries', 'nombre': 2316},
#  {'_id': 'Restaurants', 'nombre': 1089},
#  {'_id': 'Audio', 'nombre': 164},
#  {'_id': 'Design', 'nombre': 1641},
#  {'_id': 'Bacon', 'nombre': 78},
#  {'_id': 'Photography', 'nombre': 2239},
#  {'_id': 'Journalism', 'nombre': 672},
#  {'_id': 'Digital Art', 'nombre': 524},
#  {'_id': 'Cookbooks', 'nombre': 217},
#  {'_id': 'Web', 'nombre': 2017},
#  {'_id': 'Knitting', 'nombre': 78},
#  {'_id': 'Candles', 'nombre': 168},
#  {'_id': 'Shorts', 'nombre': 4857},
#  {'_id': 'Gadgets', 'nombre': 1210},
#  {'_id': 'Ready-to-wear', 'nombre': 332},
#  {'_id': 'Performances', 'nombre': 414},
#  {'_id': 'Indie Rock', 'nombre': 2192},
#  {'_id': 'Poetry', 'nombre': 532},
#  {'_id': 'Horror', 'nombre': 525},
#  {'_id': 'Installations', 'nombre': 178},
#  {'_id': 'Sound', 'nombre': 255},
#  {'_id': 'Kids', 'nombre': 109},
#  {'_id': 'Woodworking', 'nombre': 433},
#  {'_id': 'Art Books', 'nombre': 1065},
#  {'_id': 'Civic Design', 'nombre': 130},
#  {'_id': 'Weaving', 'nombre': 38},
#  {'_id': 'Literary Journals', 'nombre': 118},
#  {'_id': 'Animals', 'nombre': 97},
#  {'_id': "Farmer's Markets", 'nombre': 175},
#  {'_id': 'Plays', 'nombre': 539},
#  {'_id': 'Fiction', 'nombre': 3703},
#  {'_id': 'Spaces', 'nombre': 331},
#  {'_id': 'Music', 'nombre': 6229},
#  {'_id': 'Tabletop Games', 'nombre': 5581},
#  {'_id': 'Festivals', 'nombre': 313},
#  {'_id': 'Conceptual Art', 'nombre': 393},
#  {'_id': 'Apparel', 'nombre': 2827},
#  {'_id': 'World Music', 'nombre': 850},
#  {'_id': 'People', 'nombre': 440},
#  {'_id': 'Print', 'nombre': 288},
#  {'_id': 'Couture', 'nombre': 108},
#  {'_id': 'Electronic Music', 'nombre': 858},
#  {'_id': 'Software', 'nombre': 1194},
#  {'_id': 'Periodicals', 'nombre': 517},
#  {'_id': 'Pet Fashion', 'nombre': 51},
#  {'_id': 'Small Batch', 'nombre': 701},
#  {'_id': 'Experimental', 'nombre': 357},
#  {'_id': 'Embroidery', 'nombre': 49},
#  {'_id': 'Webcomics', 'nombre': 259}]

# %% [markdown]
# ## Question 4

# %%
cur = collection.find({"$and":[{"launched":{"$lt": pd.to_datetime("2016-01-01 00:00:00")}}, {"country":"FR"}]}).count()
cur
# Out:
# 330

# %% [markdown]
# ## Question 5

# %%
cur = collection.find({"$and":[{"usd pledged":{"$gt": 200000}}, {"country":"US"}]})
list(cur)
# Out:
# [{'_id': 217543389,
#   'name': 'The uKeg Pressurized Growler for Fresh Beer',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-12-08',
#   'goal': 75000.0,
#   'launched': datetime.datetime(2014, 10, 15, 6, 34, 48),
#   'pledged': 1559525.68,
#   'state': 'successful',
#   'backers': 10293,
#   'country': 'US',
#   'usd pledged': 1559525.68,
#   'usd_pledged_real': 1559525.68},
#  {'_id': 909248984,
#   'name': 'Redux COURG - Hybrid Watches with Missions to Tackle',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-08-20',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 7, 21, 19, 1, 41),
#   'pledged': 692912.0,
#   'state': 'successful',
#   'backers': 2200,
#   'country': 'US',
#   'usd pledged': 692912.0,
#   'usd_pledged_real': 692912.0},
#  {'_id': 1688905333,
#   'name': 'Legion Solar - A Better Way to Energy Independence',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-06-18',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2016, 5, 3, 16, 0, 22),
#   'pledged': 277524.0,
#   'state': 'successful',
#   'backers': 399,
#   'country': 'US',
#   'usd pledged': 277524.0,
#   'usd_pledged_real': 277524.0},
#  {'_id': 447408232,
#   'name': 'Edyn: Welcome to the connected garden.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-07-08',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2014, 6, 5, 13, 50, 13),
#   'pledged': 384201.63,
#   'state': 'successful',
#   'backers': 2336,
#   'country': 'US',
#   'usd pledged': 384201.63,
#   'usd_pledged_real': 384201.63},
#  {'_id': 1919184836,
#   'name': 'Period Panties',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2014-03-09',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2014, 2, 7, 15, 32, 50),
#   'pledged': 404763.3,
#   'state': 'successful',
#   'backers': 9550,
#   'country': 'US',
#   'usd pledged': 404763.3,
#   'usd_pledged_real': 404763.3},
#  {'_id': 828587276,
#   'name': 'Shadowrun: Hong Kong',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-02-17',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2015, 1, 13, 18, 45, 24),
#   'pledged': 1204726.47,
#   'state': 'successful',
#   'backers': 31497,
#   'country': 'US',
#   'usd pledged': 1204726.47,
#   'usd_pledged_real': 1204726.47},
#  {'_id': 821637012,
#   'name': 'Kurt Vonnegut: Unstuck in Time',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-03-10',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2015, 2, 10, 14, 5, 34),
#   'pledged': 300319.0,
#   'state': 'successful',
#   'backers': 3755,
#   'country': 'US',
#   'usd pledged': 300319.0,
#   'usd_pledged_real': 300319.0},
#  {'_id': 1075169964,
#   'name': 'Battle Worlds: Kronos - Turn-based strategy revisited',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-04-28',
#   'goal': 120000.0,
#   'launched': datetime.datetime(2013, 3, 19, 10, 44, 15),
#   'pledged': 260235.9,
#   'state': 'successful',
#   'backers': 7564,
#   'country': 'US',
#   'usd pledged': 260235.9,
#   'usd_pledged_real': 260235.9},
#  {'_id': 1339618489,
#   'name': 'Hie Diaper Bag: Your New Best Friend',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-07-15',
#   'goal': 60000.0,
#   'launched': datetime.datetime(2017, 6, 12, 17, 54, 56),
#   'pledged': 395666.0,
#   'state': 'successful',
#   'backers': 1882,
#   'country': 'US',
#   'usd pledged': 259582.0,
#   'usd_pledged_real': 395666.0},
#  {'_id': 1751772364,
#   'name': 'Hemingwrite - A Distraction Free Digital Typewriter',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-01-23',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 12, 10, 18, 58, 8),
#   'pledged': 342471.0,
#   'state': 'successful',
#   'backers': 1096,
#   'country': 'US',
#   'usd pledged': 342471.0,
#   'usd_pledged_real': 342471.0},
#  {'_id': 956638568,
#   'name': 'Dobot: Robotic Arm for Everyone, Arduino & Open Source',
#   'category': 'Robots',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-11-04',
#   'goal': 36000.0,
#   'launched': datetime.datetime(2015, 9, 15, 14, 53, 19),
#   'pledged': 615600.0,
#   'state': 'successful',
#   'backers': 1208,
#   'country': 'US',
#   'usd pledged': 615600.0,
#   'usd_pledged_real': 615600.0},
#  {'_id': 1299968108,
#   'name': 'PolySmooth & Polysher: 3D Prints Without Layers',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-05-25',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2016, 4, 25, 17, 59, 57),
#   'pledged': 433860.0,
#   'state': 'successful',
#   'backers': 1343,
#   'country': 'US',
#   'usd pledged': 433860.0,
#   'usd_pledged_real': 433860.0},
#  {'_id': 726969634,
#   'name': 'Sails of Glory - Miniatures Ship Combat',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-04-16',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2013, 3, 5, 8, 54, 47),
#   'pledged': 276745.0,
#   'state': 'successful',
#   'backers': 1183,
#   'country': 'US',
#   'usd pledged': 276745.0,
#   'usd_pledged_real': 276745.0},
#  {'_id': 1587924529,
#   'name': 'The Temperfect Mug: Coffee and Tea at The Perfect Temp',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-01-01',
#   'goal': 23500.0,
#   'launched': datetime.datetime(2013, 11, 24, 23, 26, 14),
#   'pledged': 269271.01,
#   'state': 'successful',
#   'backers': 4903,
#   'country': 'US',
#   'usd pledged': 269271.01,
#   'usd_pledged_real': 269271.01},
#  {'_id': 1957695328,
#   'name': 'Planetary Annihilation - A Next Generation RTS',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-09-14',
#   'goal': 900000.0,
#   'launched': datetime.datetime(2012, 8, 15, 21, 20, 10),
#   'pledged': 2229344.36,
#   'state': 'successful',
#   'backers': 44162,
#   'country': 'US',
#   'usd pledged': 2229344.36,
#   'usd_pledged_real': 2229344.36},
#  {'_id': 1572015807,
#   'name': "Aeon's End: War Eternal",
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-04-21',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2017, 3, 21, 16, 15, 57),
#   'pledged': 434703.0,
#   'state': 'successful',
#   'backers': 3890,
#   'country': 'US',
#   'usd pledged': 201364.0,
#   'usd_pledged_real': 434703.0},
#  {'_id': 1497942355,
#   'name': 'XERISCOPE: The Orbiting Mechanical Automatic Watch by XERIC',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-12-21',
#   'goal': 40000.0,
#   'launched': datetime.datetime(2013, 11, 6, 15, 21, 46),
#   'pledged': 444370.38,
#   'state': 'successful',
#   'backers': 1148,
#   'country': 'US',
#   'usd pledged': 444370.38,
#   'usd_pledged_real': 444370.38},
#  {'_id': 1709793760,
#   'name': 'Canary in a Coal Mine',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-11-23',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2013, 10, 22, 18, 44, 25),
#   'pledged': 212962.22,
#   'state': 'successful',
#   'backers': 2593,
#   'country': 'US',
#   'usd pledged': 212962.22,
#   'usd_pledged_real': 212962.22},
#  {'_id': 851609835,
#   'name': 'Akaneiro: Demon Hunters',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-02-03',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2013, 1, 4, 0, 27, 43),
#   'pledged': 204680.93,
#   'state': 'successful',
#   'backers': 2681,
#   'country': 'US',
#   'usd pledged': 204680.93,
#   'usd_pledged_real': 204680.93},
#  {'_id': 271631066,
#   'name': 'MYTH: Journeyman',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-03-29',
#   'goal': 80000.0,
#   'launched': datetime.datetime(2015, 3, 9, 16, 58, 49),
#   'pledged': 972886.0,
#   'state': 'successful',
#   'backers': 4739,
#   'country': 'US',
#   'usd pledged': 972886.0,
#   'usd_pledged_real': 972886.0},
#  {'_id': 874722536,
#   'name': 'The ultimate sleep sanctuary: Kokoon EEG headphones',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-07-10',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2015, 5, 11, 17, 0, 32),
#   'pledged': 1936825.0,
#   'state': 'successful',
#   'backers': 8489,
#   'country': 'US',
#   'usd pledged': 1936825.0,
#   'usd_pledged_real': 1936825.0},
#  {'_id': 644614031,
#   'name': "Iota: Never lose sight of what's important.",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-14',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 7, 15, 8, 19, 5),
#   'pledged': 282155.0,
#   'state': 'successful',
#   'backers': 1657,
#   'country': 'US',
#   'usd pledged': 282155.0,
#   'usd_pledged_real': 282155.0},
#  {'_id': 121842661,
#   'name': 'Pixy (CMUcam5): a fast, easy-to-use vision sensor',
#   'category': 'DIY Electronics',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-09-14',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2013, 8, 15, 8, 15, 31),
#   'pledged': 274352.11,
#   'state': 'successful',
#   'backers': 2802,
#   'country': 'US',
#   'usd pledged': 274352.11,
#   'usd_pledged_real': 274352.11},
#  {'_id': 1349593857,
#   'name': 'Reissue of the 1975 NASA Graphics Standards Manual.',
#   'category': 'Graphic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-10-05',
#   'goal': 158000.0,
#   'launched': datetime.datetime(2015, 9, 1, 5, 56, 35),
#   'pledged': 941966.92,
#   'state': 'successful',
#   'backers': 8798,
#   'country': 'US',
#   'usd pledged': 941966.92,
#   'usd_pledged_real': 941966.92},
#  {'_id': 1834526569,
#   'name': 'Unsung Story: Tale of the Guardians',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-02-15',
#   'goal': 600000.0,
#   'launched': datetime.datetime(2014, 1, 14, 19, 3, 30),
#   'pledged': 660126.51,
#   'state': 'successful',
#   'backers': 15824,
#   'country': 'US',
#   'usd pledged': 660126.51,
#   'usd_pledged_real': 660126.51},
#  {'_id': 1067930555,
#   'name': 'Radian 2: Time Lapse, Motion, and Wireless Camera Control',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-05',
#   'goal': 153471.0,
#   'launched': datetime.datetime(2015, 5, 7, 18, 58, 56),
#   'pledged': 272238.0,
#   'state': 'successful',
#   'backers': 916,
#   'country': 'US',
#   'usd pledged': 272238.0,
#   'usd_pledged_real': 272238.0},
#  {'_id': 350259914,
#   'name': "Notion: Be home, even when you're not.",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-16',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2014, 9, 16, 17, 54, 46),
#   'pledged': 281655.51,
#   'state': 'successful',
#   'backers': 1338,
#   'country': 'US',
#   'usd pledged': 281655.51,
#   'usd_pledged_real': 281655.51},
#  {'_id': 749406436,
#   'name': 'Hoverboard: The Next Evolution in Personal Electric Mobility',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-22',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 9, 17, 16, 39, 3),
#   'pledged': 257275.0,
#   'state': 'failed',
#   'backers': 239,
#   'country': 'US',
#   'usd pledged': 257275.0,
#   'usd_pledged_real': 257275.0},
#  {'_id': 867411036,
#   'name': 'The Duchess - A Gaming Table from BoardGameTables.com',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-07-13',
#   'goal': 40000.0,
#   'launched': datetime.datetime(2016, 6, 9, 15, 43, 47),
#   'pledged': 2592231.77,
#   'state': 'successful',
#   'backers': 3364,
#   'country': 'US',
#   'usd pledged': 1570447.77,
#   'usd_pledged_real': 2592231.77},
#  {'_id': 2128094718,
#   'name': 'Code Monkey Save World',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2013-05-15',
#   'goal': 39000.0,
#   'launched': datetime.datetime(2013, 4, 15, 15, 18, 36),
#   'pledged': 340270.07,
#   'state': 'successful',
#   'backers': 8452,
#   'country': 'US',
#   'usd pledged': 340270.07,
#   'usd_pledged_real': 340270.07},
#  {'_id': 1253340997,
#   'name': 'Worldï¿½s first roast-grind-brew coffee machine',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-12-08',
#   'goal': 135000.0,
#   'launched': datetime.datetime(2013, 11, 12, 15, 0, 6),
#   'pledged': 681461.0,
#   'state': 'successful',
#   'backers': 2254,
#   'country': 'US',
#   'usd pledged': 681461.0,
#   'usd_pledged_real': 681461.0},
#  {'_id': 1036153335,
#   'name': 'MagSphere & MagBounce Flash Diffusers - by MagMod',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-12-04',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2014, 10, 29, 15, 10, 2),
#   'pledged': 310348.0,
#   'state': 'successful',
#   'backers': 2322,
#   'country': 'US',
#   'usd pledged': 310348.0,
#   'usd_pledged_real': 310348.0},
#  {'_id': 731137767,
#   'name': 'Finex Cast Iron Skillet: A Beloved Classic Updated',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-11-18',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2013, 10, 17, 2, 51, 37),
#   'pledged': 211027.66,
#   'state': 'successful',
#   'backers': 1558,
#   'country': 'US',
#   'usd pledged': 211027.66,
#   'usd_pledged_real': 211027.66},
#  {'_id': 459943590,
#   'name': 'Ctrl+Alt+Del 1.0: The Box Set',
#   'category': 'Anthologies',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2015-06-03',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2015, 5, 4, 6, 5, 45),
#   'pledged': 665725.94,
#   'state': 'successful',
#   'backers': 5553,
#   'country': 'US',
#   'usd pledged': 665725.94,
#   'usd_pledged_real': 665725.94},
#  {'_id': 925988701,
#   'name': 'Art Story',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-23',
#   'goal': 350000.0,
#   'launched': datetime.datetime(2013, 7, 7, 23, 34, 52),
#   'pledged': 365670.0,
#   'state': 'successful',
#   'backers': 1785,
#   'country': 'US',
#   'usd pledged': 365670.0,
#   'usd_pledged_real': 365670.0},
#  {'_id': 926038987,
#   'name': "H-Hour: World's Elite",
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-07-07',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2013, 6, 7, 23, 0, 45),
#   'pledged': 252662.28,
#   'state': 'successful',
#   'backers': 2772,
#   'country': 'US',
#   'usd pledged': 252662.28,
#   'usd_pledged_real': 252662.28},
#  {'_id': 1911751690,
#   'name': 'Dungeon of Doom: Handcrafted Game Terrain by Dwarven Forge',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-07-12',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2017, 6, 17, 17, 0, 9),
#   'pledged': 3055118.0,
#   'state': 'successful',
#   'backers': 2897,
#   'country': 'US',
#   'usd pledged': 1397310.0,
#   'usd_pledged_real': 3055118.0},
#  {'_id': 1310046506,
#   'name': 'Click - The First Watch Band Adapter for Apple Watch!',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-04-18',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 3, 18, 23, 35, 57),
#   'pledged': 216436.0,
#   'state': 'successful',
#   'backers': 5538,
#   'country': 'US',
#   'usd pledged': 216436.0,
#   'usd_pledged_real': 216436.0},
#  {'_id': 443600622,
#   'name': 'Passion Planner: Get One, Give One',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-11-24',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 10, 13, 19, 0, 52),
#   'pledged': 706287.0,
#   'state': 'successful',
#   'backers': 16335,
#   'country': 'US',
#   'usd pledged': 706287.0,
#   'usd_pledged_real': 706287.0},
#  {'_id': 22304643,
#   'name': 'Kill Doctor Lucky',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-11-14',
#   'goal': 40000.0,
#   'launched': datetime.datetime(2015, 10, 13, 21, 1, 1),
#   'pledged': 210086.5,
#   'state': 'successful',
#   'backers': 2711,
#   'country': 'US',
#   'usd pledged': 210086.5,
#   'usd_pledged_real': 210086.5},
#  {'_id': 1026598212,
#   'name': 'Numenera: Into the Ninth World',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-09-10',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 8, 5, 18, 4, 36),
#   'pledged': 417560.0,
#   'state': 'successful',
#   'backers': 3317,
#   'country': 'US',
#   'usd pledged': 417560.0,
#   'usd_pledged_real': 417560.0},
#  {'_id': 248979774,
#   'name': 'ZRRO - Play 300,000 touch games on your TV!',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-03-31',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2015, 2, 17, 19, 20, 19),
#   'pledged': 200392.0,
#   'state': 'successful',
#   'backers': 762,
#   'country': 'US',
#   'usd pledged': 200392.0,
#   'usd_pledged_real': 200392.0},
#  {'_id': 1636168806,
#   'name': 'StoneTether - The Smallest Tracking Device at Long Range',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-13',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2014, 11, 3, 17, 39, 21),
#   'pledged': 366199.0,
#   'state': 'successful',
#   'backers': 6927,
#   'country': 'US',
#   'usd pledged': 366199.0,
#   'usd_pledged_real': 366199.0},
#  {'_id': 415727459,
#   'name': 'FormBox: A Desktop Vacuum Former That Makes Beautiful Things',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-06-03',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2016, 5, 2, 19, 22, 23),
#   'pledged': 588775.55,
#   'state': 'successful',
#   'backers': 1745,
#   'country': 'US',
#   'usd pledged': 588775.55,
#   'usd_pledged_real': 588775.55},
#  {'_id': 815224727,
#   'name': 'Superior Motors: Community Restaurant & Farm Ecosystem',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-01-07',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2013, 12, 4, 18, 56, 58),
#   'pledged': 310225.01,
#   'state': 'successful',
#   'backers': 2026,
#   'country': 'US',
#   'usd pledged': 310225.01,
#   'usd_pledged_real': 310225.01},
#  {'_id': 926266608,
#   'name': 'Modbook Pro X ï¿½ 15.4" Retina Quad-Core Mac OS X Tablet',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-07',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2014, 7, 30, 18, 57, 35),
#   'pledged': 318244.34,
#   'state': 'successful',
#   'backers': 331,
#   'country': 'US',
#   'usd pledged': 318244.34,
#   'usd_pledged_real': 318244.34},
#  {'_id': 697445050,
#   'name': 'Remix IO - A 4K, Nougat-powered, All-in-One device',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-19',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2016, 10, 20, 16, 57, 37),
#   'pledged': 598268.0,
#   'state': 'successful',
#   'backers': 4435,
#   'country': 'US',
#   'usd pledged': 233222.0,
#   'usd_pledged_real': 598268.0},
#  {'_id': 849119531,
#   'name': 'Fief - France 1429',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-02-11',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2013, 12, 28, 20, 1, 26),
#   'pledged': 408519.36,
#   'state': 'successful',
#   'backers': 4021,
#   'country': 'US',
#   'usd pledged': 408519.36,
#   'usd_pledged_real': 408519.36},
#  {'_id': 776266348,
#   'name': 'Posthuman',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-04-24',
#   'goal': 27000.0,
#   'launched': datetime.datetime(2015, 3, 25, 22, 52, 43),
#   'pledged': 346071.0,
#   'state': 'successful',
#   'backers': 5323,
#   'country': 'US',
#   'usd pledged': 346071.0,
#   'usd_pledged_real': 346071.0},
#  {'_id': 1942255469,
#   'name': 'Luminoodle: Versatile USB Lighting Solution',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-10-15',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 9, 15, 16, 0, 10),
#   'pledged': 388464.1,
#   'state': 'successful',
#   'backers': 6768,
#   'country': 'US',
#   'usd pledged': 388464.1,
#   'usd_pledged_real': 388464.1},
#  {'_id': 1192070348,
#   'name': 'Glowdeck - A companion for your smartphone.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-05-01',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2014, 3, 18, 20, 52, 29),
#   'pledged': 209669.0,
#   'state': 'successful',
#   'backers': 956,
#   'country': 'US',
#   'usd pledged': 209669.0,
#   'usd_pledged_real': 209669.0},
#  {'_id': 1967287711,
#   'name': 'tinyTesla: the Little Singing Tesla Coil Anyone Can Build',
#   'category': 'DIY Electronics',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-15',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2014, 7, 16, 19, 48, 29),
#   'pledged': 336271.05,
#   'state': 'successful',
#   'backers': 1568,
#   'country': 'US',
#   'usd pledged': 336271.05,
#   'usd_pledged_real': 336271.05},
#  {'_id': 2137602357,
#   'name': 'ZUNGLE : Wear the Beats',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-07-16',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2016, 6, 16, 16, 41, 54),
#   'pledged': 1947035.0,
#   'state': 'successful',
#   'backers': 11349,
#   'country': 'US',
#   'usd pledged': 207044.0,
#   'usd_pledged_real': 1947035.0},
#  {'_id': 1288353288,
#   'name': 'ORION4Sight: Sunglasses On Steroids',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-13',
#   'goal': 9000.0,
#   'launched': datetime.datetime(2014, 8, 12, 18, 37, 49),
#   'pledged': 348449.0,
#   'state': 'successful',
#   'backers': 2881,
#   'country': 'US',
#   'usd pledged': 348449.0,
#   'usd_pledged_real': 348449.0},
#  {'_id': 1669948790,
#   'name': 'Unknown Armies Third Edition Roleplaying Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-04-29',
#   'goal': 40000.0,
#   'launched': datetime.datetime(2016, 3, 30, 21, 33, 25),
#   'pledged': 266084.45,
#   'state': 'successful',
#   'backers': 2819,
#   'country': 'US',
#   'usd pledged': 266084.45,
#   'usd_pledged_real': 266084.45},
#  {'_id': 474144967,
#   'name': 'Crowfall - Throne War PC MMO',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-03-26',
#   'goal': 800000.0,
#   'launched': datetime.datetime(2015, 2, 24, 14, 0, 26),
#   'pledged': 1766204.58,
#   'state': 'successful',
#   'backers': 16936,
#   'country': 'US',
#   'usd pledged': 1766204.58,
#   'usd_pledged_real': 1766204.58},
#  {'_id': 969897193,
#   'name': 'Create wide-angle Bubble Bokeh: Trioplan 35+ Fine Art Lens',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'USD',
#   'deadline': '2017-04-13',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2017, 3, 9, 16, 0, 22),
#   'pledged': 595893.23,
#   'state': 'successful',
#   'backers': 774,
#   'country': 'US',
#   'usd pledged': 239730.21,
#   'usd_pledged_real': 595893.23},
#  {'_id': 1317644491,
#   'name': "Remix Mini - The World's First True Android PC.",
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-08-29',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 7, 15, 14, 55, 55),
#   'pledged': 1647155.12,
#   'state': 'successful',
#   'backers': 21975,
#   'country': 'US',
#   'usd pledged': 1647155.12,
#   'usd_pledged_real': 1647155.12},
#  {'_id': 434718627,
#   'name': 'Little Witch Academia 2',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-08',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2013, 7, 9, 5, 31, 42),
#   'pledged': 625518.12,
#   'state': 'successful',
#   'backers': 7938,
#   'country': 'US',
#   'usd pledged': 625518.12,
#   'usd_pledged_real': 625518.12},
#  {'_id': 375709459,
#   'name': 'Dead State: The Zombie Survival RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-07-05',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2012, 6, 5, 23, 31, 17),
#   'pledged': 332635.58,
#   'state': 'successful',
#   'backers': 10096,
#   'country': 'US',
#   'usd pledged': 332635.58,
#   'usd_pledged_real': 332635.58},
#  {'_id': 1117814212,
#   'name': 'SnapJet: Turn your smartphone into a polaroid film printer!',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-20',
#   'goal': 155000.0,
#   'launched': datetime.datetime(2014, 11, 19, 21, 2, 7),
#   'pledged': 210449.0,
#   'state': 'successful',
#   'backers': 1486,
#   'country': 'US',
#   'usd pledged': 210449.0,
#   'usd_pledged_real': 210449.0},
#  {'_id': 879838135,
#   'name': 'BLAZAR: Aluminum Bluetooth Speaker & Artist Collaboration',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-09-01',
#   'goal': 90000.0,
#   'launched': datetime.datetime(2013, 7, 23, 16, 6, 37),
#   'pledged': 323696.99,
#   'state': 'successful',
#   'backers': 1769,
#   'country': 'US',
#   'usd pledged': 323696.99,
#   'usd_pledged_real': 323696.99},
#  {'_id': 881278489,
#   'name': "Halo Back: World's First Smart Screen Protector",
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-12',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 5, 12, 18, 31, 5),
#   'pledged': 251089.0,
#   'state': 'successful',
#   'backers': 8018,
#   'country': 'US',
#   'usd pledged': 251089.0,
#   'usd_pledged_real': 251089.0},
#  {'_id': 1066172240,
#   'name': 'Rum & Bones: Second Tide',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-04-29',
#   'goal': 80000.0,
#   'launched': datetime.datetime(2016, 4, 11, 21, 1, 1),
#   'pledged': 917864.02,
#   'state': 'successful',
#   'backers': 5794,
#   'country': 'US',
#   'usd pledged': 917864.02,
#   'usd_pledged_real': 917864.02},
#  {'_id': 63646255,
#   'name': 'Girl Genius Volume 12 Printing and Reprint Frenzy!',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2013-06-03',
#   'goal': 55000.0,
#   'launched': datetime.datetime(2013, 5, 15, 20, 29, 28),
#   'pledged': 389079.03,
#   'state': 'successful',
#   'backers': 4441,
#   'country': 'US',
#   'usd pledged': 389079.03,
#   'usd_pledged_real': 389079.03},
#  {'_id': 355247056,
#   'name': 'Project 562: Changing The Way We See Native America (Phase2)',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2014-02-21',
#   'goal': 54000.0,
#   'launched': datetime.datetime(2014, 1, 20, 11, 46, 39),
#   'pledged': 213461.49,
#   'state': 'successful',
#   'backers': 3882,
#   'country': 'US',
#   'usd pledged': 213461.49,
#   'usd_pledged_real': 213461.49},
#  {'_id': 1890358928,
#   'name': "De La Soul's NEW ALBUM",
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2015-05-02',
#   'goal': 110000.0,
#   'launched': datetime.datetime(2015, 3, 30, 18, 3, 13),
#   'pledged': 600874.82,
#   'state': 'successful',
#   'backers': 11169,
#   'country': 'US',
#   'usd pledged': 600874.82,
#   'usd_pledged_real': 600874.82},
#  {'_id': 1653048335,
#   'name': 'Machine of Death: The Game of Creative Assassination',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-03-20',
#   'goal': 23000.0,
#   'launched': datetime.datetime(2013, 2, 14, 22, 55, 11),
#   'pledged': 556596.17,
#   'state': 'successful',
#   'backers': 10666,
#   'country': 'US',
#   'usd pledged': 556596.17,
#   'usd_pledged_real': 556596.17},
#  {'_id': 224730709,
#   'name': 'DRAGON WARRIORS:   a feature film starring James Marsters',
#   'category': 'Fantasy',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-05-19',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2014, 4, 19, 18, 27, 18),
#   'pledged': 216260.28,
#   'state': 'successful',
#   'backers': 1628,
#   'country': 'US',
#   'usd pledged': 216260.28,
#   'usd_pledged_real': 216260.28},
#  {'_id': 1864259007,
#   'name': 'Xeko',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-07-21',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2012, 5, 22, 16, 29, 50),
#   'pledged': 257870.61,
#   'state': 'successful',
#   'backers': 973,
#   'country': 'US',
#   'usd pledged': 257870.61,
#   'usd_pledged_real': 257870.61},
#  {'_id': 502128093,
#   'name': 'Electric Objects: A Computer Made for Art',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-07',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2014, 7, 8, 16, 35, 51),
#   'pledged': 787612.73,
#   'state': 'successful',
#   'backers': 2246,
#   'country': 'US',
#   'usd pledged': 787612.73,
#   'usd_pledged_real': 787612.73},
#  {'_id': 645282827,
#   'name': 'Sleep Shepherd Blue: A Sleep Tracker that HELPS You Sleep',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-03-25',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2016, 2, 24, 13, 53, 3),
#   'pledged': 675184.5,
#   'state': 'successful',
#   'backers': 3233,
#   'country': 'US',
#   'usd pledged': 675184.5,
#   'usd_pledged_real': 675184.5},
#  {'_id': 577887742,
#   'name': 'Redefining Swiss Automatic Watches by LIV',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-02-19',
#   'goal': 40000.0,
#   'launched': datetime.datetime(2016, 1, 20, 21, 0, 42),
#   'pledged': 1119029.85,
#   'state': 'successful',
#   'backers': 2169,
#   'country': 'US',
#   'usd pledged': 1119029.85,
#   'usd_pledged_real': 1119029.85},
#  {'_id': 863432111,
#   'name': 'The Lomography Daguerreotype Achromat 2.9/64 Art Lens',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-05-10',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2016, 4, 6, 10, 58, 36),
#   'pledged': 927576.13,
#   'state': 'successful',
#   'backers': 2036,
#   'country': 'US',
#   'usd pledged': 927576.13,
#   'usd_pledged_real': 927576.13},
#  {'_id': 1829930859,
#   'name': "PancakeBot - The world's first pancake printer!",
#   'category': 'Robots',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-04-10',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 3, 6, 15, 41, 52),
#   'pledged': 460584.0,
#   'state': 'successful',
#   'backers': 2074,
#   'country': 'US',
#   'usd pledged': 460584.0,
#   'usd_pledged_real': 460584.0},
#  {'_id': 1842403099,
#   'name': 'The Cyanide & Happiness Show',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-03-18',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2013, 2, 15, 8, 55, 35),
#   'pledged': 770309.28,
#   'state': 'successful',
#   'backers': 14242,
#   'country': 'US',
#   'usd pledged': 770309.28,
#   'usd_pledged_real': 770309.28},
#  {'_id': 1301018404,
#   'name': 'LOAD the Board Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-06-08',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2016, 5, 19, 20, 0, 28),
#   'pledged': 215471.52,
#   'state': 'successful',
#   'backers': 1558,
#   'country': 'US',
#   'usd pledged': 215471.52,
#   'usd_pledged_real': 215471.52},
#  {'_id': 726799615,
#   'name': 'PARKE: Premium Active Denim - Engineered for Performance',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2013-11-01',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2013, 9, 17, 14, 45, 29),
#   'pledged': 221509.0,
#   'state': 'successful',
#   'backers': 1784,
#   'country': 'US',
#   'usd pledged': 221509.0,
#   'usd_pledged_real': 221509.0},
#  {'_id': 1877182337,
#   'name': 'PENXO | The most minimalistic 2mm lead holder pencil',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-06-11',
#   'goal': 8800.0,
#   'launched': datetime.datetime(2015, 5, 6, 6, 35, 46),
#   'pledged': 334211.0,
#   'state': 'successful',
#   'backers': 5764,
#   'country': 'US',
#   'usd pledged': 334211.0,
#   'usd_pledged_real': 334211.0},
#  {'_id': 1732240067,
#   'name': '1001 Knights',
#   'category': 'Anthologies',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2016-02-26',
#   'goal': 70000.0,
#   'launched': datetime.datetime(2016, 1, 27, 16, 51, 50),
#   'pledged': 299192.28,
#   'state': 'successful',
#   'backers': 3289,
#   'country': 'US',
#   'usd pledged': 299192.28,
#   'usd_pledged_real': 299192.28},
#  {'_id': 61500846,
#   'name': 'BedJet v2: Sleep inducing climate control just for your Bed',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-09-13',
#   'goal': 24000.0,
#   'launched': datetime.datetime(2015, 8, 5, 19, 6, 38),
#   'pledged': 1363381.0,
#   'state': 'successful',
#   'backers': 4023,
#   'country': 'US',
#   'usd pledged': 1363381.0,
#   'usd_pledged_real': 1363381.0},
#  {'_id': 3968895,
#   'name': 'RiffTrax will Riff GODZILLA & ANACONDA in Cinemas Nationwide',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-06-12',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2014, 5, 13, 1, 16, 38),
#   'pledged': 265011.68,
#   'state': 'successful',
#   'backers': 4887,
#   'country': 'US',
#   'usd pledged': 265011.68,
#   'usd_pledged_real': 265011.68},
#  {'_id': 345927017,
#   'name': 'PocketScan',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-07-16',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2014, 6, 16, 14, 41, 13),
#   'pledged': 542732.32,
#   'state': 'successful',
#   'backers': 4586,
#   'country': 'US',
#   'usd pledged': 542732.32,
#   'usd_pledged_real': 542732.32},
#  {'_id': 1908063428,
#   'name': 'Kiwi 3 - OBD Car to Smartphone Interface Reinvented',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-08-07',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 6, 23, 20, 19, 53),
#   'pledged': 272851.0,
#   'state': 'successful',
#   'backers': 3801,
#   'country': 'US',
#   'usd pledged': 272851.0,
#   'usd_pledged_real': 272851.0},
#  {'_id': 1438957994,
#   'name': "Boss Fight Studio's Vitruvian H.A.C.K.S. Action Figures",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-07-12',
#   'goal': 75000.0,
#   'launched': datetime.datetime(2014, 6, 3, 4, 52, 35),
#   'pledged': 412270.0,
#   'state': 'successful',
#   'backers': 1198,
#   'country': 'US',
#   'usd pledged': 412270.0,
#   'usd_pledged_real': 412270.0},
#  {'_id': 137993716,
#   'name': 'SpeedX Leopard | the first ever smart aero road bike',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-04-22',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2016, 3, 23, 15, 1, 47),
#   'pledged': 2319876.0,
#   'state': 'successful',
#   'backers': 1251,
#   'country': 'US',
#   'usd pledged': 2319876.0,
#   'usd_pledged_real': 2319876.0},
#  {'_id': 656587023,
#   'name': 'Ticwatch S & E: A Truly Optimized Smartwatch',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-08-18',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2017, 7, 11, 18, 58, 15),
#   'pledged': 3203762.0,
#   'state': 'successful',
#   'backers': 19251,
#   'country': 'US',
#   'usd pledged': 774259.0,
#   'usd_pledged_real': 3203762.0},
#  {'_id': 857799723,
#   'name': 'RiffTrax Live 2015: THE ROOM, MIAMI CONNECTION, SHARKNADO 2!',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-03-21',
#   'goal': 75000.0,
#   'launched': datetime.datetime(2015, 2, 19, 21, 13, 23),
#   'pledged': 250303.24,
#   'state': 'successful',
#   'backers': 3842,
#   'country': 'US',
#   'usd pledged': 250303.24,
#   'usd_pledged_real': 250303.24},
#  {'_id': 981149095,
#   'name': '"Be Here Now" ï¿½ The Andy Whitfield Story',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-07-23',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2012, 6, 8, 22, 4, 11),
#   'pledged': 302810.91,
#   'state': 'successful',
#   'backers': 5265,
#   'country': 'US',
#   'usd pledged': 302810.91,
#   'usd_pledged_real': 302810.91},
#  {'_id': 1859509147,
#   'name': 'Super Dungeon Explore: Legends',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-11-11',
#   'goal': 80000.0,
#   'launched': datetime.datetime(2015, 10, 21, 20, 59, 58),
#   'pledged': 1290522.32,
#   'state': 'successful',
#   'backers': 6611,
#   'country': 'US',
#   'usd pledged': 1290522.32,
#   'usd_pledged_real': 1290522.32},
#  {'_id': 1552929469,
#   'name': "CHIP - The World's First Nine Dollar Computer",
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-06',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 5, 7, 17, 6, 2),
#   'pledged': 2071927.56,
#   'state': 'successful',
#   'backers': 39560,
#   'country': 'US',
#   'usd pledged': 2071927.56,
#   'usd_pledged_real': 2071927.56},
#  {'_id': 1280589435,
#   'name': 'New Studio Album from Toad the Wet Sprocket!',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-08-04',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2013, 6, 5, 23, 36, 52),
#   'pledged': 264762.72,
#   'state': 'successful',
#   'backers': 6304,
#   'country': 'US',
#   'usd pledged': 264762.72,
#   'usd_pledged_real': 264762.72},
#  {'_id': 1650287708,
#   'name': 'Capture Camera Clip System',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2011-07-16',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2011, 5, 2, 20, 22, 51),
#   'pledged': 364698.64,
#   'state': 'successful',
#   'backers': 5258,
#   'country': 'US',
#   'usd pledged': 364698.64,
#   'usd_pledged_real': 364698.64},
#  {'_id': 1218533935,
#   'name': '3Dsimo mini - Make your vision come true',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-12',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2015, 8, 28, 13, 40, 19),
#   'pledged': 229958.0,
#   'state': 'successful',
#   'backers': 1822,
#   'country': 'US',
#   'usd pledged': 229958.0,
#   'usd_pledged_real': 229958.0},
#  {'_id': 1318194565,
#   'name': 'FUGU LUGGAGE: One Case For All Your Needs',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-12-13',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2014, 11, 3, 17, 25, 53),
#   'pledged': 433684.0,
#   'state': 'successful',
#   'backers': 1541,
#   'country': 'US',
#   'usd pledged': 433684.0,
#   'usd_pledged_real': 433684.0},
#  {'_id': 348146014,
#   'name': 'Artisan Dice Does Handcrafted Polyhedrals',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-05-01',
#   'goal': 9000.0,
#   'launched': datetime.datetime(2013, 3, 12, 20, 8, 35),
#   'pledged': 291920.97,
#   'state': 'successful',
#   'backers': 1174,
#   'country': 'US',
#   'usd pledged': 291920.97,
#   'usd_pledged_real': 291920.97},
#  {'_id': 538111099,
#   'name': 'MagBeam - Fresnel Lens Flash Extender + Gobos, by MagMod',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-04-15',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2016, 3, 1, 14, 58, 40),
#   'pledged': 301234.0,
#   'state': 'successful',
#   'backers': 1776,
#   'country': 'US',
#   'usd pledged': 301234.0,
#   'usd_pledged_real': 301234.0},
#  {'_id': 1577713248,
#   'name': 'Raise3D 3D Printers - Raise the Standard of 3D Printing',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-11-13',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 10, 14, 19, 59, 45),
#   'pledged': 445892.0,
#   'state': 'successful',
#   'backers': 348,
#   'country': 'US',
#   'usd pledged': 445892.0,
#   'usd_pledged_real': 445892.0},
#  {'_id': 185659343,
#   'name': 'UBIK UNO: The Bezeless Smartphone at an Unbeatable Price',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-09-04',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2015, 7, 21, 13, 47, 44),
#   'pledged': 241925.0,
#   'state': 'successful',
#   'backers': 766,
#   'country': 'US',
#   'usd pledged': 241925.0,
#   'usd_pledged_real': 241925.0},
#  {'_id': 355636922,
#   'name': 'MAGBELT - A magnetic belt that fits perfectly to your waist.',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-07-19',
#   'goal': 7500.0,
#   'launched': datetime.datetime(2015, 6, 3, 12, 6, 42),
#   'pledged': 583544.56,
#   'state': 'successful',
#   'backers': 9707,
#   'country': 'US',
#   'usd pledged': 583544.56,
#   'usd_pledged_real': 583544.56},
#  {'_id': 703110157,
#   'name': 'Beasts of the Mesozoic: Raptor Series Action Figures',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-05-27',
#   'goal': 125000.0,
#   'launched': datetime.datetime(2016, 4, 27, 18, 0, 50),
#   'pledged': 351753.52,
#   'state': 'successful',
#   'backers': 2661,
#   'country': 'US',
#   'usd pledged': 351753.52,
#   'usd_pledged_real': 351753.52},
#  {'_id': 1336092748,
#   'name': "Beastgrip Pro the world's best camera rig for smartphones",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-04-24',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 3, 25, 16, 56, 6),
#   'pledged': 265897.0,
#   'state': 'successful',
#   'backers': 1752,
#   'country': 'US',
#   'usd pledged': 265897.0,
#   'usd_pledged_real': 265897.0},
#  {'_id': 1931115500,
#   'name': 'Karmaka ï¿½ A tactical card game for 2-4 souls',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-02-18',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2016, 1, 19, 15, 48, 3),
#   'pledged': 220852.58,
#   'state': 'successful',
#   'backers': 7198,
#   'country': 'US',
#   'usd pledged': 220852.58,
#   'usd_pledged_real': 220852.58},
#  {'_id': 1897028933,
#   'name': 'Revols - Premium Quick Custom-Fit Wireless Earphones',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-01-08',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2015, 11, 9, 13, 57, 15),
#   'pledged': 2530756.27,
#   'state': 'successful',
#   'backers': 10569,
#   'country': 'US',
#   'usd pledged': 2530756.27,
#   'usd_pledged_real': 2530756.27},
#  {'_id': 664982962,
#   'name': 'Princess Awesome',
#   'category': 'Childrenswear',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-03-05',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2015, 2, 3, 16, 21, 57),
#   'pledged': 215691.0,
#   'state': 'successful',
#   'backers': 3218,
#   'country': 'US',
#   'usd pledged': 215691.0,
#   'usd_pledged_real': 215691.0},
#  {'_id': 487048791,
#   'name': 'HAVOK - Disrupting Luxury Watches',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-03-07',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 1, 6, 17, 41, 50),
#   'pledged': 443777.05,
#   'state': 'successful',
#   'backers': 4435,
#   'country': 'US',
#   'usd pledged': 443777.05,
#   'usd_pledged_real': 443777.05},
#  {'_id': 197718885,
#   'name': 'Saving Capitalism - Starring Robert Reich',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-05-06',
#   'goal': 256500.0,
#   'launched': datetime.datetime(2016, 4, 6, 23, 4, 40),
#   'pledged': 298436.53,
#   'state': 'successful',
#   'backers': 3790,
#   'country': 'US',
#   'usd pledged': 298436.53,
#   'usd_pledged_real': 298436.53},
#  {'_id': 257342308,
#   'name': 'goTenna Mesh: Off-Grid, People-Powered Connectivity Anywhere',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-10-28',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2016, 9, 28, 15, 46, 22),
#   'pledged': 582473.0,
#   'state': 'successful',
#   'backers': 2902,
#   'country': 'US',
#   'usd pledged': 201555.0,
#   'usd_pledged_real': 582473.0},
#  {'_id': 1420270001,
#   'name': 'Grim Dawn',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-05-19',
#   'goal': 280000.0,
#   'launched': datetime.datetime(2012, 4, 17, 12, 34, 43),
#   'pledged': 537515.31,
#   'state': 'successful',
#   'backers': 12457,
#   'country': 'US',
#   'usd pledged': 537515.31,
#   'usd_pledged_real': 537515.31},
#  {'_id': 355273044,
#   'name': 'Portable Console for PC games - PGS',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-07-31',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2016, 7, 1, 0, 1, 58),
#   'pledged': 302836.0,
#   'state': 'canceled',
#   'backers': 1184,
#   'country': 'US',
#   'usd pledged': 325322.0,
#   'usd_pledged_real': 302836.0},
#  {'_id': 591612744,
#   'name': 'Fuel3D: A handheld 3D scanner for less than $1000',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-09-01',
#   'goal': 75000.0,
#   'launched': datetime.datetime(2013, 7, 31, 10, 8, 32),
#   'pledged': 325343.48,
#   'state': 'successful',
#   'backers': 437,
#   'country': 'US',
#   'usd pledged': 325343.48,
#   'usd_pledged_real': 325343.48},
#  {'_id': 806581386,
#   'name': 'The BIG Turtle Shellï¿½: Rugged, Wireless BoomBox & Power Bank',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-05-01',
#   'goal': 40000.0,
#   'launched': datetime.datetime(2014, 4, 1, 16, 1, 30),
#   'pledged': 315222.2,
#   'state': 'successful',
#   'backers': 1789,
#   'country': 'US',
#   'usd pledged': 315222.2,
#   'usd_pledged_real': 315222.2},
#  {'_id': 251988143,
#   'name': 'BOMBERCO.COM - "Best Damn Duffel Bag"',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-12-13',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2014, 10, 14, 15, 33, 24),
#   'pledged': 430393.01,
#   'state': 'successful',
#   'backers': 5102,
#   'country': 'US',
#   'usd pledged': 430393.01,
#   'usd_pledged_real': 430393.01},
#  {'_id': 1498002503,
#   'name': 'Fairytale Games: The Miniatures Campaign',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-10-22',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2013, 9, 17, 19, 31, 5),
#   'pledged': 236625.13,
#   'state': 'successful',
#   'backers': 1269,
#   'country': 'US',
#   'usd pledged': 236625.13,
#   'usd_pledged_real': 236625.13},
#  {'_id': 2093901087,
#   'name': 'KNK Force - The first dual head plotter with a true Z axis',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-23',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 9, 18, 12, 4, 22),
#   'pledged': 226817.99,
#   'state': 'successful',
#   'backers': 394,
#   'country': 'US',
#   'usd pledged': 226817.99,
#   'usd_pledged_real': 226817.99},
#  {'_id': 1584790657,
#   'name': 'Lightpack ï¿½ ambient backlight for your displays',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-05-31',
#   'goal': 261962.0,
#   'launched': datetime.datetime(2013, 4, 25, 10, 45, 23),
#   'pledged': 500784.27,
#   'state': 'successful',
#   'backers': 5812,
#   'country': 'US',
#   'usd pledged': 500784.27,
#   'usd_pledged_real': 500784.27},
#  {'_id': 1296367883,
#   'name': 'Onewheel :: The Self-Balancing Electric Skateboard',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-01-27',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2014, 1, 6, 20, 52, 9),
#   'pledged': 630862.55,
#   'state': 'successful',
#   'backers': 1015,
#   'country': 'US',
#   'usd pledged': 630862.55,
#   'usd_pledged_real': 630862.55},
#  {'_id': 965102512,
# ...
#   'pledged': 219996.0,
#   'state': 'successful',
#   'backers': 1220,
#   'country': 'US',
#   'usd pledged': 219996.0,
#   'usd_pledged_real': 219996.0},
#  {'_id': 1523269305,
#   'name': 'Dragonï¿½s Lair: The Movie (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-11-26',
#   'goal': 550000.0,
#   'launched': datetime.datetime(2015, 10, 26, 17, 0, 47),
#   'pledged': 241579.82,
#   'state': 'canceled',
#   'backers': 2954,
#   'country': 'US',
#   'usd pledged': 241579.82,
#   'usd_pledged_real': 241579.82},
#  {'_id': 1232061249,
#   'name': 'Warpath - The Sci-fi Battle Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-10-12',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 9, 21, 14, 30, 4),
#   'pledged': 484917.16,
#   'state': 'successful',
#   'backers': 3355,
#   'country': 'US',
#   'usd pledged': 484917.16,
#   'usd_pledged_real': 484917.16},
#  {'_id': 2124046131,
#   'name': 'Boss Monster: The Next Level',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-04-28',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 4, 13, 15, 3, 50),
#   'pledged': 335618.85,
#   'state': 'successful',
#   'backers': 6891,
#   'country': 'US',
#   'usd pledged': 335618.85,
#   'usd_pledged_real': 335618.85},
#  {'_id': 152665462,
#   'name': 'An Honest Liar: The Amazing Randi Story',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-02-15',
#   'goal': 148000.0,
#   'launched': datetime.datetime(2013, 1, 14, 19, 0, 29),
#   'pledged': 246989.16,
#   'state': 'successful',
#   'backers': 3096,
#   'country': 'US',
#   'usd pledged': 246989.16,
#   'usd_pledged_real': 246989.16},
#  {'_id': 1719674104,
#   'name': 'Petcube ï¿½ stay closer to your pet',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-11-05',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2013, 9, 24, 16, 57, 1),
#   'pledged': 251225.99,
#   'state': 'successful',
#   'backers': 1758,
#   'country': 'US',
#   'usd pledged': 251225.99,
#   'usd_pledged_real': 251225.99},
#  {'_id': 1616591982,
#   'name': 'AllSteady-6Pro DSLR/Red 3-Axis Gimbal Stabilizer',
#   'category': 'Camera Equipment',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-02-26',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 2, 4, 23, 38, 7),
#   'pledged': 206751.45,
#   'state': 'successful',
#   'backers': 136,
#   'country': 'US',
#   'usd pledged': 206751.45,
#   'usd_pledged_real': 206751.45},
#  {'_id': 227311545,
#   'name': 'BOOKNITURE- Furniture Hidden in a Book',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-03-18',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 2, 6, 16, 41, 6),
#   'pledged': 449969.0,
#   'state': 'successful',
#   'backers': 4007,
#   'country': 'US',
#   'usd pledged': 449969.0,
#   'usd_pledged_real': 449969.0},
#  {'_id': 1928575021,
#   'name': 'PowerUp 3.0 - Smartphone Controlled Paper Airplane',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-01-25',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2013, 11, 26, 15, 59, 58),
#   'pledged': 1232612.55,
#   'state': 'successful',
#   'backers': 21412,
#   'country': 'US',
#   'usd pledged': 1232612.55,
#   'usd_pledged_real': 1232612.55},
#  {'_id': 1652718766,
#   'name': 'Ube WiFi Connected Smart Light Dimmer',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-04-05',
#   'goal': 280000.0,
#   'launched': datetime.datetime(2013, 2, 19, 3, 20, 32),
#   'pledged': 307600.01,
#   'state': 'successful',
#   'backers': 1308,
#   'country': 'US',
#   'usd pledged': 307600.01,
#   'usd_pledged_real': 307600.01},
#  {'_id': 985162833,
#   'name': 'Full-size reissue of the NYCTA Graphics Standards Manual.',
#   'category': 'Graphic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-10-10',
#   'goal': 108000.0,
#   'launched': datetime.datetime(2014, 9, 10, 13, 15, 43),
#   'pledged': 802812.9,
#   'state': 'successful',
#   'backers': 6718,
#   'country': 'US',
#   'usd pledged': 802812.9,
#   'usd_pledged_real': 802812.9},
#  {'_id': 1758139953,
#   'name': 'The Gamers: Hands of Fate',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-09-08',
#   'goal': 320000.0,
#   'launched': datetime.datetime(2012, 7, 18, 4, 57, 56),
#   'pledged': 405916.78,
#   'state': 'successful',
#   'backers': 4311,
#   'country': 'US',
#   'usd pledged': 405916.78,
#   'usd_pledged_real': 405916.78},
#  {'_id': 567888025,
#   'name': 'HomeBiogas 2.0: Transforms Your Food Waste Into Clean Energy',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-12-13',
#   'goal': 75000.0,
#   'launched': datetime.datetime(2017, 11, 1, 12, 50, 14),
#   'pledged': 490319.0,
#   'state': 'successful',
#   'backers': 677,
#   'country': 'US',
#   'usd pledged': 241707.0,
#   'usd_pledged_real': 490319.0},
#  {'_id': 1332810988,
#   'name': 'Pen Type-A : A minimal pen',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2011-08-15',
#   'goal': 2500.0,
#   'launched': datetime.datetime(2011, 7, 16, 20, 16, 54),
#   'pledged': 281989.75,
#   'state': 'successful',
#   'backers': 4048,
#   'country': 'US',
#   'usd pledged': 281989.75,
#   'usd_pledged_real': 281989.75},
#  {'_id': 612880945,
#   'name': 'Point: A softer take on home security.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-04',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2014, 11, 4, 17, 59, 41),
#   'pledged': 238366.0,
#   'state': 'successful',
#   'backers': 2005,
#   'country': 'US',
#   'usd pledged': 238366.0,
#   'usd_pledged_real': 238366.0},
#  {'_id': 729484586,
#   'name': 'Time of Legends: Joan of Arc',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-11-10',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2017, 10, 10, 21, 0, 5),
#   'pledged': 2152285.02,
#   'state': 'successful',
#   'backers': 9987,
#   'country': 'US',
#   'usd pledged': 355231.0,
#   'usd_pledged_real': 2152285.02},
#  {'_id': 658110891,
#   'name': 'Smart Herb Garden by Click & Grow',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-04-30',
#   'goal': 75000.0,
#   'launched': datetime.datetime(2013, 3, 27, 13, 2, 49),
#   'pledged': 625851.72,
#   'state': 'successful',
#   'backers': 10477,
#   'country': 'US',
#   'usd pledged': 625851.72,
#   'usd_pledged_real': 625851.72},
#  {'_id': 1948827936,
#   'name': 'Through the Breach: A Malifaux Roleplaying Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-01-11',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2012, 11, 28, 23, 17, 40),
#   'pledged': 243945.43,
#   'state': 'successful',
#   'backers': 1546,
#   'country': 'US',
#   'usd pledged': 243945.43,
#   'usd_pledged_real': 243945.43},
#  {'_id': 2096075781,
#   'name': 'Pathfinder: Kingmaker',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-07-12',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2017, 6, 6, 16, 32, 25),
#   'pledged': 909057.32,
#   'state': 'successful',
#   'backers': 18351,
#   'country': 'US',
#   'usd pledged': 257647.0,
#   'usd_pledged_real': 909057.32},
#  {'_id': 1812220599,
#   'name': "Noke: The World's First Bluetooth Padlock",
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-17',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2014, 8, 18, 13, 2, 49),
#   'pledged': 652828.81,
#   'state': 'successful',
#   'backers': 6108,
#   'country': 'US',
#   'usd pledged': 652828.81,
#   'usd_pledged_real': 652828.81},
#  {'_id': 1911111579,
#   'name': 'Two Guys SpaceVenture - by the creators of Space Quest',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-06-12',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2012, 5, 8, 19, 27, 38),
#   'pledged': 539767.64,
#   'state': 'successful',
#   'backers': 10809,
#   'country': 'US',
#   'usd pledged': 539767.64,
#   'usd_pledged_real': 539767.64},
#  {'_id': 450099426,
#   'name': 'The Everyday Backpack, Tote, and Sling',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-09-10',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2016, 7, 13, 0, 47, 35),
#   'pledged': 6565782.5,
#   'state': 'successful',
#   'backers': 26359,
#   'country': 'US',
#   'usd pledged': 1462611.0,
#   'usd_pledged_real': 6565782.5},
#  {'_id': 1645606141,
#   'name': 'PrioVR: Suit up. Game on.',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-03-31',
#   'goal': 75000.0,
#   'launched': datetime.datetime(2014, 2, 14, 16, 0, 6),
#   'pledged': 322103.09,
#   'state': 'successful',
#   'backers': 854,
#   'country': 'US',
#   'usd pledged': 322103.09,
#   'usd_pledged_real': 322103.09},
#  {'_id': 1901440175,
#   'name': 'Customizable 3D Printed Tabletop Miniatures',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-02-18',
#   'goal': 95000.0,
#   'launched': datetime.datetime(2014, 1, 13, 19, 59, 58),
#   'pledged': 360403.27,
#   'state': 'successful',
#   'backers': 5189,
#   'country': 'US',
#   'usd pledged': 360403.27,
#   'usd_pledged_real': 360403.27},
#  {'_id': 1590570924,
#   'name': 'The Digital Bolex: The 1st Affordable Digital Cinema Camera',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-04-11',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2012, 3, 12, 21, 41, 11),
#   'pledged': 262661.5,
#   'state': 'successful',
#   'backers': 440,
#   'country': 'US',
#   'usd pledged': 262661.5,
#   'usd_pledged_real': 262661.5},
#  {'_id': 738065144,
#   'name': "8-in-1 EVOLUTION BRA: The World's Most Advanced Bra",
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-10-24',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 9, 14, 16, 7, 43),
#   'pledged': 1105177.5,
#   'state': 'successful',
#   'backers': 13642,
#   'country': 'US',
#   'usd pledged': 1105177.5,
#   'usd_pledged_real': 1105177.5},
#  {'_id': 279794621,
#   'name': 'Mega Manï¿½ The Board Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-01-19',
#   'goal': 70000.0,
#   'launched': datetime.datetime(2013, 12, 12, 18, 58, 35),
#   'pledged': 415041.0,
#   'state': 'successful',
#   'backers': 2639,
#   'country': 'US',
#   'usd pledged': 415041.0,
#   'usd_pledged_real': 415041.0},
#  {'_id': 1719494931,
#   'name': 'Obduction',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-11-16',
#   'goal': 1100000.0,
#   'launched': datetime.datetime(2013, 10, 17, 15, 6, 31),
#   'pledged': 1321306.44,
#   'state': 'successful',
#   'backers': 22195,
#   'country': 'US',
#   'usd pledged': 1321306.44,
#   'usd_pledged_real': 1321306.44},
#  {'_id': 1323185961,
#   'name': 'Sprite: portable and rugged.  A totally different drone.',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-14',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2015, 5, 15, 5, 52, 37),
#   'pledged': 406061.0,
#   'state': 'successful',
#   'backers': 532,
#   'country': 'US',
#   'usd pledged': 406061.0,
#   'usd_pledged_real': 406061.0},
#  {'_id': 363567675,
#   'name': '1979 REVOLUTION: Black Friday',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-12-16',
#   'goal': 395000.0,
#   'launched': datetime.datetime(2013, 11, 13, 13, 22, 42),
#   'pledged': 304741.5,
#   'state': 'failed',
#   'backers': 1653,
#   'country': 'US',
#   'usd pledged': 304741.5,
#   'usd_pledged_real': 304741.5},
#  {'_id': 1127031239,
#   'name': 'TAKTIK: Premium Protection System for the iPhone',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-07-21',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2012, 6, 21, 16, 43, 39),
#   'pledged': 680568.09,
#   'state': 'successful',
#   'backers': 4597,
#   'country': 'US',
#   'usd pledged': 680568.09,
#   'usd_pledged_real': 680568.09},
#  {'_id': 472676658,
#   'name': 'Deathfire: Ruins of Nethermore RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-12-07',
#   'goal': 390000.0,
#   'launched': datetime.datetime(2013, 11, 6, 21, 1),
#   'pledged': 204344.55,
#   'state': 'failed',
#   'backers': 3815,
#   'country': 'US',
#   'usd pledged': 204344.55,
#   'usd_pledged_real': 204344.55},
#  {'_id': 1113497210,
#   'name': 'Xia: Legends of a Drift System',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-06-22',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2013, 5, 17, 9, 17, 18),
#   'pledged': 346772.24,
#   'state': 'successful',
#   'backers': 3293,
#   'country': 'US',
#   'usd pledged': 346772.24,
#   'usd_pledged_real': 346772.24},
#  {'_id': 940858853,
#   'name': 'The Tribal Collection | Wooden Polarized Shades',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-07-01',
#   'goal': 6500.0,
#   'launched': datetime.datetime(2015, 6, 1, 7, 13, 59),
#   'pledged': 276164.01,
#   'state': 'successful',
#   'backers': 3196,
#   'country': 'US',
#   'usd pledged': 276164.01,
#   'usd_pledged_real': 276164.01},
#  {'_id': 247076610,
#   'name': 'Time of EVE: The Movie on Blu-ray',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-06-22',
#   'goal': 18000.0,
#   'launched': datetime.datetime(2013, 5, 24, 1, 31, 23),
#   'pledged': 215433.9,
#   'state': 'successful',
#   'backers': 2711,
#   'country': 'US',
#   'usd pledged': 215433.9,
#   'usd_pledged_real': 215433.9},
#  {'_id': 1270104074,
#   'name': 'Republique by Camouflaj + Logan',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-05-12',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2012, 4, 10, 14, 37, 30),
#   'pledged': 555662.86,
#   'state': 'successful',
#   'backers': 11611,
#   'country': 'US',
#   'usd pledged': 555662.86,
#   'usd_pledged_real': 555662.86},
#  {'_id': 344582158,
#   'name': 'Hub+ for USB-C: Get your MacBook ports back.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-16',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2015, 5, 5, 19, 8, 49),
#   'pledged': 883460.8,
#   'state': 'successful',
#   'backers': 8019,
#   'country': 'US',
#   'usd pledged': 883460.8,
#   'usd_pledged_real': 883460.8},
#  {'_id': 170672682,
#   'name': 'The Field Skillet: Lighter, Smoother Cast Iron',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-04-07',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2016, 3, 7, 2, 25, 16),
#   'pledged': 1633361.53,
#   'state': 'successful',
#   'backers': 12553,
#   'country': 'US',
#   'usd pledged': 1633361.53,
#   'usd_pledged_real': 1633361.53},
#  {'_id': 78391894,
#   'name': 'Handcrafted Dress Shoes Reinvented for the Modern Gentleman',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-04-27',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2017, 3, 14, 12, 43, 55),
#   'pledged': 1265430.42,
#   'state': 'successful',
#   'backers': 4422,
#   'country': 'US',
#   'usd pledged': 339955.15,
#   'usd_pledged_real': 1265430.42},
#  {'_id': 238266124,
#   'name': 'Giant Unicorn Lamp',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-07-28',
#   'goal': 28500.0,
#   'launched': datetime.datetime(2015, 6, 23, 16, 54, 26),
#   'pledged': 250876.0,
#   'state': 'successful',
#   'backers': 3306,
#   'country': 'US',
#   'usd pledged': 250876.0,
#   'usd_pledged_real': 250876.0}]

# %% [markdown]
# ## Question 6

# %%
cur = collection.find({"name":{'$regex' : 'Sport', '$options' : 'i'}})
list(cur)
# Out:
# [{'_id': 802281658,
#   'name': 'Sportswear range',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'AUD',
#   'deadline': '2014-08-23',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2014, 7, 24, 5, 14, 52),
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'AU',
#   'usd pledged': 18.7569048,
#   'usd_pledged_real': 18.675880100849763},
#  {'_id': 2143543297,
#   'name': 'SPORTSFRIENDS featuring Johann Sebastian Joust',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-12-10',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2012, 11, 8, 22, 55, 34),
#   'pledged': 152451.25,
#   'state': 'successful',
#   'backers': 4146,
#   'country': 'US',
#   'usd pledged': 152451.25,
#   'usd_pledged_real': 152451.25},
#  {'_id': 1838460041,
#   'name': 'Mount Systems for Recreation Sports & Film (GoPro) Lighting',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-16',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 5, 12, 18, 34, 28),
#   'pledged': 12442.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 12442.0,
#   'usd_pledged_real': 12442.0},
#  {'_id': 369230992,
#   'name': 'ULTIMMADMAN - action sports apparel   #JustBeTough',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2012-10-13',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2012, 9, 10, 3, 48, 17),
#   'pledged': 60.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': 1773369191,
#   'name': '2Rare Taylor photo Magazine: Amazing Women and sports cars',
#   'category': 'Photobooks',
#   'main_category': 'Photography',
#   'currency': 'USD',
#   'deadline': '2017-10-23',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2017, 9, 28, 1, 32, 49),
#   'pledged': 65.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 65.0},
#  {'_id': 767518055,
#   'name': 'E-GoBox: Revolutionary Sports Capsule Dispenser',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-08-09',
#   'goal': 60000.0,
#   'launched': datetime.datetime(2017, 7, 10, 5, 51, 37),
#   'pledged': 300.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 225.0,
#   'usd_pledged_real': 300.0},
#  {'_id': 2109408750,
#   'name': 'Biz Sports Weekly',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'GBP',
#   'deadline': '2016-08-19',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2016, 7, 20, 16, 15, 57),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 2.617595476795016},
#  {'_id': 22743603,
#   'name': 'Hugodrawings Sports Wear',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'GBP',
#   'deadline': '2016-07-18',
#   'goal': 3000.0,
#   'launched': datetime.datetime(2016, 6, 18, 12, 4, 39),
#   'pledged': 455.0,
#   'state': 'failed',
#   'backers': 14,
#   'country': 'GB',
#   'usd pledged': 590.3465499,
#   'usd_pledged_real': 595.8226936423754},
#  {'_id': 1747603310,
#   'name': 'SHOE-LOCK Sportswear:  No more laces',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-04-11',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2015, 3, 2, 21, 43, 38),
#   'pledged': 2275.0,
#   'state': 'successful',
#   'backers': 47,
#   'country': 'US',
#   'usd pledged': 2275.0,
#   'usd_pledged_real': 2275.0},
#  {'_id': 1453145888,
#   'name': 'silentsportsusa celebrating the power of the human spirit!',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2013-01-06',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2012, 12, 7, 3, 59, 20),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 2035064292,
#   'name': 'SPORTS END TABLES',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-09-24',
#   'goal': 60000.0,
#   'launched': datetime.datetime(2015, 8, 25, 19, 34, 14),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 1265998595,
#   'name': 'Modular Army Transports',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'CAD',
#   'deadline': '2016-08-14',
#   'goal': 82000.0,
#   'launched': datetime.datetime(2016, 7, 15, 1, 48, 6),
#   'pledged': 4761.95,
#   'state': 'failed',
#   'backers': 26,
#   'country': 'CA',
#   'usd pledged': 1977.8116288454999,
#   'usd_pledged_real': 3707.528807225163},
#  {'_id': 1362109613,
#   'name': 'LA LAKERS Inspired Sports + Lifestyle Jewelry for the Fans',
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-11-04',
#   'goal': 5100.0,
#   'launched': datetime.datetime(2016, 10, 4, 19, 14, 36),
#   'pledged': 2228.0,
#   'state': 'failed',
#   'backers': 34,
#   'country': 'US',
#   'usd pledged': 525.0,
#   'usd_pledged_real': 2228.0},
#  {'_id': 2144020477,
#   'name': 'ST Impact Ball: Reduce play and sport related brain injuries',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-11-20',
#   'goal': 45000.0,
#   'launched': datetime.datetime(2014, 10, 21, 21, 6, 48),
#   'pledged': 80.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 80.0,
#   'usd_pledged_real': 80.0},
#  {'_id': 1423364226,
#   'name': 'SportsFix - The end of not knowing who to play with',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-02-05',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 1, 6, 22, 42, 26),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 321623835,
#   'name': 'DV8 Sports: Golf Without Obstacles',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-07-15',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2014, 6, 10, 8, 35, 40),
#   'pledged': 85442.0,
#   'state': 'successful',
#   'backers': 170,
#   'country': 'US',
#   'usd pledged': 85442.0,
#   'usd_pledged_real': 85442.0},
#  {'_id': 1178595391,
#   'name': 'ICUBALLING: Live youth Sports fundraising (HQ)',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-04-10',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2014, 3, 3, 15, 2, 47),
#   'pledged': 460.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 460.0,
#   'usd_pledged_real': 460.0},
#  {'_id': 334859686,
#   'name': 'Reversing the downward spiral of youth sports through Fans',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-05-28',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2015, 4, 28, 14, 34, 8),
#   'pledged': 300.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 300.0,
#   'usd_pledged_real': 300.0},
#  {'_id': 1672240130,
#   'name': 'WarriorteX - 100% American Made Performance Sportswear',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-11-07',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2016, 9, 23, 17, 23, 38),
#   'pledged': 737.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 250.0,
#   'usd_pledged_real': 737.0},
#  {'_id': 205654323,
#   'name': 'Sports, Fitness and Faith magazine',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2016-05-13',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2016, 4, 13, 19, 5, 24),
#   'pledged': 127.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 127.0,
#   'usd_pledged_real': 127.0},
#  {'_id': 2147349697,
#   'name': 'RELAJ Sports Water Bottle  - SHAPED FOR SAFETY',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-05-04',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2014, 3, 20, 0, 41, 30),
#   'pledged': 4095.0,
#   'state': 'failed',
#   'backers': 77,
#   'country': 'US',
#   'usd pledged': 4095.0,
#   'usd_pledged_real': 4095.0},
#  {'_id': 644756884,
#   'name': 'FanFix Sports - Present. Discuss. Host. Change.',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2015-09-27',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 8, 28, 16, 8, 13),
#   'pledged': 145.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 145.0,
#   'usd_pledged_real': 145.0},
#  {'_id': 552869945,
#   'name': 'the Indiana Sports Report',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2014-08-24',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2014, 7, 10, 17, 45, 10),
#   'pledged': 110.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 110.0,
#   'usd_pledged_real': 110.0},
#  {'_id': 1293757259,
#   'name': 'Unique handmade leather sports roses',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2014-08-26',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2014, 8, 6, 22, 29, 49),
#   'pledged': 27.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 27.0,
#   'usd_pledged_real': 27.0},
#  {'_id': 1128295395,
#   'name': 'Orion EV   Affordable Electric Transportation',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-02-04',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2015, 1, 5, 20, 5, 23),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1696158836,
#   'name': 'Sports Card Magazine is ready!',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2013-02-21',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2013, 1, 13, 1, 12, 18),
#   'pledged': 590.0,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'US',
#   'usd pledged': 590.0,
#   'usd_pledged_real': 590.0},
#  {'_id': 865678989,
#   'name': 'Avada Gaming E-Sports Organisation',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'AUD',
#   'deadline': '2014-08-20',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2014, 7, 16, 2, 15, 51),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'AU',
#   'usd pledged': 4.699446900000001,
#   'usd_pledged_real': 4.655926995064717},
#  {'_id': 1854354367,
#   'name': 'Learn a Foreign Language While Playing Sports',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-05-06',
#   'goal': 2500.0,
#   'launched': datetime.datetime(2015, 4, 21, 21, 29, 27),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1864518952,
#   'name': 'The Daily Sports Buzz TV and Web Show !',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-06',
#   'goal': 4000.0,
#   'launched': datetime.datetime(2013, 6, 6, 8, 47, 27),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 2135350794,
#   'name': 'Motor Sports Mailboxes',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2015-01-18',
#   'goal': 600000.0,
#   'launched': datetime.datetime(2014, 11, 19, 20, 20, 55),
#   'pledged': 200.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 200.0,
#   'usd_pledged_real': 200.0},
#  {'_id': 1108168046,
#   'name': 'Montana Brewery Passport',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2014-07-05',
#   'goal': 5500.0,
#   'launched': datetime.datetime(2014, 6, 4, 18, 10, 22),
#   'pledged': 5500.0,
#   'state': 'successful',
#   'backers': 105,
#   'country': 'US',
#   'usd pledged': 5500.0,
#   'usd_pledged_real': 5500.0},
#  {'_id': 15871755,
#   'name': 'SKLeague eSports',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'CAD',
#   'deadline': '2016-01-25',
#   'goal': 5500.0,
#   'launched': datetime.datetime(2016, 1, 4, 22, 0, 49),
#   'pledged': 991.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'CA',
#   'usd pledged': 715.75550771,
#   'usd_pledged_real': 704.3855284668422},
#  {'_id': 2066287444,
#   'name': 'apr?s | Premium After-Sport Seat Cover',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-03-08',
#   'goal': 7250.0,
#   'launched': datetime.datetime(2015, 2, 5, 0, 46, 43),
#   'pledged': 1760.0,
#   'state': 'failed',
#   'backers': 23,
#   'country': 'US',
#   'usd pledged': 1760.0,
#   'usd_pledged_real': 1760.0},
#  {'_id': 615962126,
#   'name': 'SUB - SPORTS UTILITY BAG - Bold, Tough, Ultra Versatile',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-04-28',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 3, 23, 17, 0, 15),
#   'pledged': 7175.0,
#   'state': 'canceled',
#   'backers': 50,
#   'country': 'US',
#   'usd pledged': 7175.0,
#   'usd_pledged_real': 7175.0},
#  {'_id': 12584764,
#   'name': 'Sports Cards Unlimited (Canceled)',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-11-15',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2015, 10, 16, 21, 19),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1146143519,
#   'name': 'Dolfin Pack Xtreme Sports Hydration System',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-05-23',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2014, 4, 23, 21, 44, 3),
#   'pledged': 11115.0,
#   'state': 'successful',
#   'backers': 198,
#   'country': 'US',
#   'usd pledged': 11115.0,
#   'usd_pledged_real': 11115.0},
#  {'_id': 995878467,
#   'name': 'ILLUMINATI TRANSPORT',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2017-01-03',
#   'goal': 3500.0,
#   'launched': datetime.datetime(2016, 12, 1, 17, 0, 10),
#   'pledged': 3983.0,
#   'state': 'successful',
#   'backers': 102,
#   'country': 'US',
#   'usd pledged': 1659.0,
#   'usd_pledged_real': 3983.0},
#  {'_id': 1870839048,
#   'name': 'Sport and Entertainment Podcast',
#   'category': 'Audio',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2015-01-29',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2015, 1, 15, 1, 13, 35),
#   'pledged': 47.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 47.0,
#   'usd_pledged_real': 47.0},
#  {'_id': 1327934829,
#   'name': "The 'ETTA EXPRESS (The Best-Kept Secret In Sports)",
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-09-22',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2012, 8, 23, 0, 34, 10),
#   'pledged': 16586.0,
#   'state': 'failed',
#   'backers': 38,
#   'country': 'US',
#   'usd pledged': 16586.0,
#   'usd_pledged_real': 16586.0},
#  {'_id': 447285607,
#   'name': 'FragSource eSports Network',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-08-24',
#   'goal': 3600.0,
#   'launched': datetime.datetime(2015, 7, 10, 13, 44, 57),
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 1750363014,
#   'name': 'Ride Skincare - Natural Skincare for Outdoor Sports',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'GBP',
#   'deadline': '2016-11-18',
#   'goal': 7000.0,
#   'launched': datetime.datetime(2016, 10, 24, 8, 32, 25),
#   'pledged': 748.0,
#   'state': 'failed',
#   'backers': 28,
#   'country': 'GB',
#   'usd pledged': 181.05082868,
#   'usd_pledged_real': 922.1362000098624},
#  {'_id': 367744027,
#   'name': 'FULL SIZE Imperial Troop Transporter (MK2 Parade Vehicle)',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2014-06-01',
#   'goal': 3500.0,
#   'launched': datetime.datetime(2014, 5, 12, 18, 8, 57),
#   'pledged': 236.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 236.0,
#   'usd_pledged_real': 236.0},
#  {'_id': 649483275,
#   'name': 'A website dedicated to Detroit sports and fans in Motown.',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2017-09-07',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2017, 8, 8, 2, 3, 56),
#   'pledged': 743.0,
#   'state': 'failed',
#   'backers': 12,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 743.0},
#  {'_id': 410012915,
#   'name': 'FIERCE Sportswear',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'GBP',
#   'deadline': '2017-03-17',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2017, 2, 15, 9, 22, 41),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.2360175514492304},
#  {'_id': 946363782,
#   'name': 'Help us Launch AGON - New Sports Medicine Apparel Brand',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-05-03',
#   'goal': 80000.0,
#   'launched': datetime.datetime(2016, 3, 4, 3, 32, 26),
#   'pledged': 19.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 19.0,
#   'usd_pledged_real': 19.0},
#  {'_id': 1126822169,
#   'name': 'Frey Sports App - We connect sports people.',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'DKK',
#   'deadline': '2017-01-11',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2016, 12, 12, 11, 30, 28),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'DK',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 759625825,
#   'name': 'Pickup Sports World',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-02-02',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2017, 1, 3, 2, 4, 52),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1332899780,
#   'name': 'iLikeitNerdy eSports arcade',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2018-01-18',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2017, 12, 19, 20, 39, 36),
#   'pledged': 1868.22,
#   'state': 'live',
#   'backers': 25,
#   'country': 'US',
#   'usd pledged': 410.0,
#   'usd_pledged_real': 1868.22},
#  {'_id': 1687313162,
#   'name': 'Create the NEW ComedySportz Improv Theatre in Richmond!',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2011-04-03',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2011, 2, 12, 0, 41, 58),
#   'pledged': 10521.0,
#   'state': 'successful',
#   'backers': 134,
#   'country': 'US',
#   'usd pledged': 10521.0,
#   'usd_pledged_real': 10521.0},
#  {'_id': 235617106,
#   'name': 'Mac OS X version of Passport Photo Plugin for Adobe Ps & Lr',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-04-25',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2017, 2, 24, 21, 1, 5),
#   'pledged': 251.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'DE',
#   'usd pledged': 158.431737,
#   'usd_pledged_real': 274.3439245390257},
#  {'_id': 844622643,
#   'name': 'Pro League E-Sports',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-08-01',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2016, 6, 20, 23, 1, 57),
#   'pledged': 500.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 500.0},
#  {'_id': 632369959,
#   'name': 'SportChat',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2017-02-26',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2016, 12, 28, 18, 5, 36),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 543613283,
#   'name': 'Vivacity ï¿½ Sportswear for Every Part of Your Day',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2013-05-09',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2013, 4, 9, 18, 26, 4),
#   'pledged': 5115.0,
#   'state': 'failed',
#   'backers': 38,
#   'country': 'US',
#   'usd pledged': 5115.0,
#   'usd_pledged_real': 5115.0},
#  {'_id': 415048408,
#   'name': '500 Level: Unique Officially Licensed Sports Tshirts',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2013-08-28',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2013, 7, 14, 19, 7, 9),
#   'pledged': 21213.0,
#   'state': 'successful',
#   'backers': 376,
#   'country': 'US',
#   'usd pledged': 21213.0,
#   'usd_pledged_real': 21213.0},
#  {'_id': 1388748869,
#   'name': 'Derbyshire Sport Scene',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'GBP',
#   'deadline': '2014-10-29',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2014, 9, 30, 0, 39, 12),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1980451798,
#   'name': '"Missing McKeesport"',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-09-21',
#   'goal': 18000.0,
#   'launched': datetime.datetime(2016, 8, 5, 15, 49),
#   'pledged': 18865.0,
#   'state': 'successful',
#   'backers': 142,
#   'country': 'US',
#   'usd pledged': 7331.0,
#   'usd_pledged_real': 18865.0},
#  {'_id': 33300581,
#   'name': 'Cyber Sports Monthly (Canceled)',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2013-01-22',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2012, 12, 23, 17, 8, 32),
#   'pledged': 162.0,
#   'state': 'canceled',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 162.0,
#   'usd_pledged_real': 162.0},
#  {'_id': 72535161,
#   'name': 'Nanaue eSports',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-02-11',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2016, 1, 28, 17, 18, 30),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1916832,
#   'name': 'Dog Power: A Look Into the Fastest Dogs & Newest Dog Sports',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-11-15',
#   'goal': 33462.0,
#   'launched': datetime.datetime(2015, 10, 16, 21, 46, 25),
#   'pledged': 34858.0,
#   'state': 'successful',
#   'backers': 389,
#   'country': 'US',
#   'usd pledged': 34858.0,
#   'usd_pledged_real': 34858.0},
#  {'_id': 1523192703,
#   'name': 'Sport Ball Bags',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-05-13',
#   'goal': 3000.0,
#   'launched': datetime.datetime(2017, 4, 13, 2, 7, 23),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1018822517,
#   'name': 'Massive LEGO Truman Sports Complex',
#   'category': 'Sculpture',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2014-08-21',
#   'goal': 16137.0,
#   'launched': datetime.datetime(2014, 7, 19, 23, 53, 29),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 784739167,
#   'name': 'KYMIRA Sport: An Evolution in Sportswear',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'GBP',
#   'deadline': '2014-05-16',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2014, 4, 16, 14, 3, 31),
#   'pledged': 13903.0,
#   'state': 'failed',
#   'backers': 58,
#   'country': 'GB',
#   'usd pledged': 23241.74047458,
#   'usd_pledged_real': 23369.528676124522},
#  {'_id': 1785700014,
#   'name': 'New Veen Multisport belt to RUN SAFE, NOT FOR YOUR LIFE.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2018-01-20',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2017, 12, 21, 11, 17, 58),
#   'pledged': 25.0,
#   'state': 'live',
#   'backers': 1,
#   'country': 'NL',
#   'usd pledged': 59.207753000000004,
#   'usd_pledged_real': 30.342383454905143},
#  {'_id': 87488242,
#   'name': 'SnapDrafts: Daily Fantasy Sports',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-04-25',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2015, 3, 26, 21, 48, 26),
#   'pledged': 500.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 500.0,
#   'usd_pledged_real': 500.0},
#  {'_id': 1959821013,
#   'name': "Get Real Girl: Sport action figures empowering today's girls",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-11-19',
#   'goal': 40000.0,
#   'launched': datetime.datetime(2016, 10, 20, 19, 15, 14),
#   'pledged': 44305.33,
#   'state': 'successful',
#   'backers': 243,
#   'country': 'US',
#   'usd pledged': 380.0,
#   'usd_pledged_real': 44305.33},
#  {'_id': 1792640178,
#   'name': 'JOIN THE MUSIC-SPORTS MOVEMENT!',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-01-06',
#   'goal': 1500.0,
#   'launched': datetime.datetime(2016, 11, 29, 15, 4, 19),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1439161310,
#   'name': 'Rohnert Park LAN Center/eSports facility',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-05-06',
#   'goal': 4000.0,
#   'launched': datetime.datetime(2014, 4, 22, 18, 35, 37),
#   'pledged': 1605.0,
#   'state': 'failed',
#   'backers': 19,
#   'country': 'US',
#   'usd pledged': 1605.0,
#   'usd_pledged_real': 1605.0},
#  {'_id': 1702194042,
#   'name': 'Tribal Rides - Transportation Networking - Self Driving Cars',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-16',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2014, 11, 11, 14, 16, 58),
#   'pledged': 1980.0,
#   'state': 'failed',
#   'backers': 18,
#   'country': 'US',
#   'usd pledged': 1980.0,
#   'usd_pledged_real': 1980.0},
#  {'_id': 422509694,
#   'name': '"American Sports Stories" - An Athletic Quest',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-05-14',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2017, 4, 14, 0, 8, 52),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 2073829586,
#   'name': 'FLootball.com- A Fantasy Football, RPG, Sports game Mashup',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-05-01',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 3, 17, 17, 1, 30),
#   'pledged': 110.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 110.0,
#   'usd_pledged_real': 110.0},
#  {'_id': 2068404129,
#   'name': 'Bordeaux Transport Simulator',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2016-12-31',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2016, 11, 1, 10, 6, 22),
#   'pledged': 150.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 158.83436752154853},
#  {'_id': 975878183,
#   'name': 'Fine Leather Passport Wallet by BankNote NYC',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-07-12',
#   'goal': 1500.0,
#   'launched': datetime.datetime(2016, 6, 1, 20, 25),
#   'pledged': 4829.0,
#   'state': 'successful',
#   'backers': 72,
#   'country': 'US',
#   'usd pledged': 4508.0,
#   'usd_pledged_real': 4829.0},
#  {'_id': 462355371,
#   'name': 'MySportsFeeds - crowd-sourced sports data for fans',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'CAD',
#   'deadline': '2015-05-01',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 4, 1, 19, 39, 17),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1050771565,
#   'name': 'The Pro Lounge / Gaming Restaurant & eSport Event Hosting',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-08-01',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2017, 6, 13, 6, 21, 48),
#   'pledged': 75.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 75.0,
#   'usd_pledged_real': 75.0},
#  {'_id': 1467805931,
#   'name': 'ellival -- creating a new brand for sports merchandise',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-02-25',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 1, 26, 18, 40, 28),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 532756831,
#   'name': 'Pixel Passport Sticker Vol.1',
#   'category': 'Graphic Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2017-10-01',
#   'goal': 750.0,
#   'launched': datetime.datetime(2017, 9, 1, 10, 47, 52),
#   'pledged': 838.0,
#   'state': 'successful',
#   'backers': 42,
#   'country': 'DE',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 981.0463714161957},
#  {'_id': 312464012,
#   'name': 'Loopio & Loopio Sport | Never lose your keys or phone again.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'GBP',
#   'deadline': '2015-06-17',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 5, 13, 23, 18, 4),
#   'pledged': 7461.0,
#   'state': 'failed',
#   'backers': 216,
#   'country': 'GB',
#   'usd pledged': 11621.51339202,
#   'usd_pledged_real': 11816.97234628908},
#  {'_id': 1222567604,
#   'name': "Altered V3 DS - World's First Dual Sport Electric Skateboard",
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-11-23',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2013, 10, 22, 21, 53, 6),
#   'pledged': 22815.0,
#   'state': 'failed',
#   'backers': 52,
#   'country': 'US',
#   'usd pledged': 22815.0,
#   'usd_pledged_real': 22815.0},
#  {'_id': 1628639695,
#   'name': 'Sports Gifts made from baseballs/footballs/sofballs',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-09-16',
#   'goal': 700.0,
#   'launched': datetime.datetime(2014, 9, 2, 16, 12, 13),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1447237424,
#   'name': 'Specialized African and Afro-descent sports magazine',
#   'category': 'Print',
#   'main_category': 'Journalism',
#   'currency': 'EUR',
#   'deadline': '2017-12-19',
#   'goal': 80000.0,
#   'launched': datetime.datetime(2017, 11, 8, 16, 1, 32),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'BE',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1191863686,
#   'name': 'Fortis Bike Racks: Transport any Bicycle on any Car or Truck',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2018-01-09',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2017, 12, 5, 20, 33, 3),
#   'pledged': 2110.0,
#   'state': 'canceled',
#   'backers': 9,
#   'country': 'US',
#   'usd pledged': 248.0,
#   'usd_pledged_real': 2110.0},
#  {'_id': 1021717834,
#   'name': 'SportKit: Accessorize your Olympus Air A01 digital camera',
#   'category': 'Camera Equipment',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-02-23',
#   'goal': 21700.0,
#   'launched': datetime.datetime(2017, 1, 24, 17, 20, 34),
#   'pledged': 279.0,
#   'state': 'canceled',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 130.0,
#   'usd_pledged_real': 279.0},
#  {'_id': 2063642423,
#   'name': 'Coachaholics: Daily Fantasy sports site with a twist',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-09-07',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2016, 8, 10, 18, 13, 53),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 918031988,
#   'name': "Good Sport Book - A Children's Book on Sportsmanship",
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2012-09-15',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2012, 8, 16, 2, 54, 40),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1901105792,
#   'name': 'Sports Emblems',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2014-12-10',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2014, 11, 10, 22, 51, 40),
#   'pledged': 6.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 6.0,
#   'usd_pledged_real': 6.0},
#  {'_id': 2105052828,
#   'name': 'Elite-Sports-Worldwide- presents all around sports socks!',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2012-07-22',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2012, 6, 22, 17, 52, 6),
#   'pledged': 100.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'_id': 114396613,
#   'name': 'The Sport Revolution on your SmartPhone',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-11-09',
#   'goal': 4650.0,
#   'launched': datetime.datetime(2016, 9, 30, 20, 48, 23),
#   'pledged': 636.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'ES',
#   'usd pledged': 113.40669254,
#   'usd_pledged_real': 693.4979118734258},
#  {'_id': 37609450,
#   'name': 'HYDROSPORTï¿½ Vest : Hydration System + Fitness Carry',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-10-08',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 9, 14, 18, 30, 53),
#   'pledged': 1591.0,
#   'state': 'canceled',
#   'backers': 20,
#   'country': 'US',
#   'usd pledged': 1591.0,
#   'usd_pledged_real': 1591.0},
#  {'_id': 599433495,
#   'name': 'Water Sports Enthusiast Clothing by Water-Borne',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2012-11-09',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2012, 10, 10, 17, 52, 29),
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 415264066,
#   'name': 'Sportfestival Buitenadem',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-04-30',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 3, 22, 10, 38, 38),
#   'pledged': 321.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'NL',
#   'usd pledged': 347.34320205,
#   'usd_pledged_real': 360.00269160890923},
#  {'_id': 1093249848,
#   'name': 'Hitting the Sweet Spot in Urban Transport: Frankentrikes',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-03-25',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2016, 2, 16, 22, 57, 25),
#   'pledged': 5512.0,
#   'state': 'canceled',
#   'backers': 16,
#   'country': 'US',
#   'usd pledged': 5512.0,
#   'usd_pledged_real': 5512.0},
#  {'_id': 1024116205,
#   'name': '2017 Support - Soccer Sports Open Data',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-01-08',
#   'goal': 500.0,
#   'launched': datetime.datetime(2016, 12, 9, 16, 48, 37),
#   'pledged': 6.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'IT',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 6.3965884861407245},
#  {'_id': 144139366,
#   'name': 'Ace eSports',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2017-02-18',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2016, 12, 20, 9, 24, 37),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'ES',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1275259290,
#   'name': 'iWhite - Sport Nutrition - Restaurant',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-11-01',
#   'goal': 140000.0,
#   'launched': datetime.datetime(2015, 9, 17, 13, 32, 30),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'DE',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 209496650,
#   'name': 'PAK performs at Hagenfesten 2010. Transport us from Brooklyn to Dala-Folda, Sweden',
#   'category': 'Jazz',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2010-07-13',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2010, 6, 2, 15, 35, 3),
#   'pledged': 1075.0,
#   'state': 'successful',
#   'backers': 31,
#   'country': 'US',
#   'usd pledged': 1075.0,
#   'usd_pledged_real': 1075.0},
#  {'_id': 1399971030,
#   'name': 'The Time Traveler - Passport Wallet Genuine Leather + RFID',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-10-08',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2016, 9, 8, 4, 37, 20),
#   'pledged': 2726.0,
#   'state': 'failed',
#   'backers': 46,
#   'country': 'US',
#   'usd pledged': 150.0,
#   'usd_pledged_real': 2726.0},
#  {'_id': 1658515944,
#   'name': 'Super Slam Dunk Touchdown: A Sports Game For Everybody!',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-03-29',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 2, 27, 3, 17),
#   'pledged': 5428.0,
#   'state': 'failed',
#   'backers': 132,
#   'country': 'US',
#   'usd pledged': 5428.0,
#   'usd_pledged_real': 5428.0},
#  {'_id': 1383708382,
#   'name': 'Outsider -The weatherproof wearable remote for action sports',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-02-04',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2017, 1, 5, 16, 41, 43),
#   'pledged': 7815.0,
#   'state': 'failed',
#   'backers': 40,
#   'country': 'US',
#   'usd pledged': 2519.0,
#   'usd_pledged_real': 7815.0},
#  {'_id': 71653776,
#   'name': 'THE MILLY BOX  : THE ULTIMATE PET TRANSPORT BOX :',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'AUD',
#   'deadline': '2015-05-21',
#   'goal': 330000.0,
#   'launched': datetime.datetime(2015, 4, 21, 17, 13, 21),
#   'pledged': 390.0,
#   'state': 'failed',
#   'backers': 9,
#   'country': 'AU',
#   'usd pledged': 304.47484469999995,
#   'usd_pledged_real': 307.4255084344948},
#  {'_id': 312991396,
#   'name': 'eSports Tournaments (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-08-30',
#   'goal': 27000.0,
#   'launched': datetime.datetime(2015, 7, 3, 17, 15, 33),
#   'pledged': 2.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 729181791,
#   'name': 'Poor Sports- iBook created by a 6 year old Creative Wizard',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2013-04-05',
#   'goal': 1500.0,
#   'launched': datetime.datetime(2013, 3, 6, 18, 54, 6),
#   'pledged': 410.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 410.0,
#   'usd_pledged_real': 410.0},
#  {'_id': 2014871717,
#   'name': 'DJBennett.com The World of SPORTING LUXURY',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-04-09',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 3, 10, 17, 1, 31),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1456633887,
#   'name': 'A Locksport Workshop with Schuyler Towne',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2011-01-14',
#   'goal': 40.0,
#   'launched': datetime.datetime(2011, 1, 10, 17, 19, 53),
#   'pledged': 108.0,
#   'state': 'successful',
#   'backers': 43,
#   'country': 'US',
#   'usd pledged': 108.0,
#   'usd_pledged_real': 108.0},
#  {'_id': 798840482,
#   'name': 'Be part of the next sports range revolution @ZeusGymClothing',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'GBP',
#   'deadline': '2013-10-16',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2013, 9, 6, 13, 6, 39),
#   'pledged': 29.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'GB',
#   'usd pledged': 45.27783427,
#   'usd_pledged_real': 46.954438003950656},
#  {'_id': 746676343,
#   'name': 'The 90 Degree Show on NBC Sports',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-10-30',
#   'goal': 1800.0,
#   'launched': datetime.datetime(2017, 9, 28, 23, 17, 29),
#   'pledged': 173.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 22.0,
#   'usd_pledged_real': 173.0},
#  {'_id': 137733484,
#   'name': "'Cursed' - The Cleveland Sports Story",
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-01-07',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2011, 11, 8, 21, 19, 16),
#   'pledged': 425.0,
#   'state': 'failed',
#   'backers': 18,
#   'country': 'US',
#   'usd pledged': 425.0,
#   'usd_pledged_real': 425.0},
#  {'_id': 1771971822,
#   'name': 'Bright Stools:  Any Sport, Any Season, Any Event.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-01-12',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2014, 11, 13, 5, 51),
#   'pledged': 2893.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 2893.0,
#   'usd_pledged_real': 2893.0},
#  {'_id': 69383759,
#   'name': '"ACTION" A Gallery Showing For Action Sports',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2010-12-09',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2010, 10, 25, 4, 29, 3),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1573405970,
#   'name': '~FrogSportsBoards~',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-03-04',
#   'goal': 162500.0,
#   'launched': datetime.datetime(2016, 1, 20, 22, 20, 37),
#   'pledged': 1160.0,
#   'state': 'failed',
#   'backers': 9,
#   'country': 'US',
#   'usd pledged': 1160.0,
#   'usd_pledged_real': 1160.0},
#  {'_id': 991949576,
#   'name': 'Your Passport to the Pelted Universe!',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-08-18',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2015, 8, 4, 17, 0, 19),
#   'pledged': 5745.34,
#   'state': 'successful',
#   'backers': 126,
#   'country': 'US',
#   'usd pledged': 5745.34,
#   'usd_pledged_real': 5745.34},
#  {'_id': 2083908527,
#   'name': 'Build a Large Scale Version  of the Airsailer Sports Balloon',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-11',
#   'goal': 47600.0,
#   'launched': datetime.datetime(2014, 8, 12, 8, 28, 36),
#   'pledged': 17.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 17.0,
#   'usd_pledged_real': 17.0},
#  {'_id': 2072875895,
#   'name': 'Odds Hacker - Sports Betting and Fantasy Sports Predictions',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-15',
#   'goal': 60000.0,
#   'launched': datetime.datetime(2015, 9, 15, 15, 45, 34),
#   'pledged': 16000.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'US',
#   'usd pledged': 16000.0,
#   'usd_pledged_real': 16000.0},
#  {'_id': 1935189722,
#   'name': 'KickFlip Mafia Action Sports Clothing',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2012-07-26',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2012, 6, 11, 22, 5, 27),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 684627152,
#   'name': 'Dream Skating Sports Planner',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-05-01',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 3, 2, 22, 24, 11),
#   'pledged': 400.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 400.0,
#   'usd_pledged_real': 400.0},
#  {'_id': 2006222883,
#   'name': 'Quakecon 2015 Documentary by WinD of XI Geforce eSports',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-05-09',
#   'goal': 1400.0,
#   'launched': datetime.datetime(2015, 4, 2, 2, 49, 24),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 95745611,
#   'name': 'McSling: Wearable Sports Equipment or Most Anything Carrier',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-07-03',
#   'goal': 3500.0,
#   'launched': datetime.datetime(2017, 6, 5, 6, 57, 27),
#   'pledged': 360.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 360.0},
#  {'_id': 2134440543,
#   'name': 'Sports Year: 365 Games in 365 Days',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2013-09-13',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2013, 8, 23, 21, 18, 2),
#   'pledged': 19690.0,
#   'state': 'failed',
#   'backers': 110,
#   'country': 'US',
#   'usd pledged': 19690.0,
#   'usd_pledged_real': 19690.0},
#  {'_id': 1961408855,
#   'name': 'Good Game, Well Played-The Story of Irish eSports.',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2016-02-03',
#   'goal': 3500.0,
#   'launched': datetime.datetime(2015, 12, 5, 12, 33, 42),
#   'pledged': 863.37,
#   'state': 'failed',
#   'backers': 15,
#   'country': 'IE',
#   'usd pledged': 943.6356440208,
#   'usd_pledged_real': 967.1446174526717},
#  {'_id': 298118471,
#   'name': "Brewer's Passport - Craft Beer & Travel Pocket Journal",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-08-24',
#   'goal': 8500.0,
#   'launched': datetime.datetime(2016, 7, 26, 16, 40, 39),
#   'pledged': 12874.0,
#   'state': 'successful',
#   'backers': 439,
#   'country': 'US',
#   'usd pledged': 2482.0,
#   'usd_pledged_real': 12874.0},
#  {'_id': 1741756528,
#   'name': 'Spotbook Spot?s for Sport?s',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-06-30',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 5, 16, 0, 35, 18),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'DE',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 595778535,
#   'name': 'Sports bag "Infinity"',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-11-12',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2016, 10, 13, 15, 38, 34),
#   'pledged': 431.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 280.0,
#   'usd_pledged_real': 431.0},
#  {'_id': 374746825,
#   'name': 'Instant, Mobile, Fantasy Sports.',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-09-19',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2013, 8, 20, 1, 23, 8),
#   'pledged': 30637.0,
#   'state': 'successful',
#   'backers': 56,
#   'country': 'US',
#   'usd pledged': 30637.0,
#   'usd_pledged_real': 30637.0},
#  {'_id': 2049335955,
#   'name': 'Innovative nursing bra built-in tank, dress and sports bra',
#   'category': 'Product Design',
# ...
#   'state': 'successful',
#   'backers': 1087,
#   'country': 'US',
#   'usd pledged': 113534.33,
#   'usd_pledged_real': 113534.33},
#  {'_id': 876821007,
#   'name': 'Papi Girl: Reinventing Sportswear For The Female Fan!',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2014-10-24',
#   'goal': 75000.0,
#   'launched': datetime.datetime(2014, 9, 24, 13, 56, 33),
#   'pledged': 3110.0,
#   'state': 'failed',
#   'backers': 31,
#   'country': 'US',
#   'usd pledged': 3110.0,
#   'usd_pledged_real': 3110.0},
#  {'_id': 144583144,
#   'name': 'TAKEOVERSports',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-02-16',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2017, 1, 17, 23, 44, 40),
#   'pledged': 35.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': 266098008,
#   'name': 'Fitness, Agility Ladder, Sports, Health, Training, wellness',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-02-09',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2017, 1, 10, 3, 24, 13),
#   'pledged': 135.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 105.0,
#   'usd_pledged_real': 135.0},
#  {'_id': 243977433,
#   'name': 'Transport travelers into space. ("spaced" Finishing Funds)',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-01-04',
#   'goal': 2475.0,
#   'launched': datetime.datetime(2013, 12, 2, 2, 50, 20),
#   'pledged': 2576.0,
#   'state': 'successful',
#   'backers': 54,
#   'country': 'US',
#   'usd pledged': 2576.0,
#   'usd_pledged_real': 2576.0},
#  {'_id': 1557793034,
#   'name': 'The Transport - A sophisticated but simple mounting system.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-07-10',
#   'goal': 75000.0,
#   'launched': datetime.datetime(2015, 6, 5, 16, 51, 31),
#   'pledged': 4053.0,
#   'state': 'failed',
#   'backers': 53,
#   'country': 'US',
#   'usd pledged': 4053.0,
#   'usd_pledged_real': 4053.0},
#  {'_id': 1832407103,
#   'name': 'Covering Catholic Sports from Youth to College and Beyond',
#   'category': 'Video',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2016-04-29',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2016, 3, 15, 16, 7, 31),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 2111331354,
#   'name': 'UK Mountain Sport Bible',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'currency': 'GBP',
#   'deadline': '2015-10-03',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 8, 14, 13, 53, 30),
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'GB',
#   'usd pledged': 31.2418478,
#   'usd_pledged_real': 30.67908146830084},
#  {'_id': 1078281579,
#   'name': 'Skyline Sports',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'CAD',
#   'deadline': '2016-12-08',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2016, 11, 17, 14, 32, 43),
#   'pledged': 277.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'CA',
#   'usd pledged': 205.92774442,
#   'usd_pledged_real': 210.21476815663655},
#  {'_id': 411567167,
#   'name': 'Sports Art History',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2016-12-31',
#   'goal': 15265.0,
#   'launched': datetime.datetime(2016, 11, 23, 13, 45, 14),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 229171863,
#   'name': 'Fanlys - Group Messaging for Sports',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-07-28',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2017, 6, 28, 21, 24, 58),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1758443651,
#   'name': 'The Kingsport Cases',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-06-02',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2013, 5, 3, 18, 58, 8),
#   'pledged': 20537.99,
#   'state': 'suspended',
#   'backers': 421,
#   'country': 'US',
#   'usd pledged': 20537.99,
#   'usd_pledged_real': 20537.99},
#  {'_id': 236292600,
#   'name': 'Win The Day - The Sport & Exercise Performance Tool-Kit',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'GBP',
#   'deadline': '2017-11-29',
#   'goal': 7000.0,
#   'launched': datetime.datetime(2017, 10, 30, 0, 28, 27),
#   'pledged': 8224.0,
#   'state': 'successful',
#   'backers': 20,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 11092.527650391152},
#  {'_id': 1841585352,
#   'name': 'Airfromthere Memories  Sports,Travel,Landmark Enthusiasts.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-03-05',
#   'goal': 70000.0,
#   'launched': datetime.datetime(2016, 1, 5, 17, 34, 6),
#   'pledged': 412.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 412.0,
#   'usd_pledged_real': 412.0},
#  {'_id': 1419386475,
#   'name': 'CALLIGURT Design - Gadget for Laptop, Sport &Travel Bag',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-12-03',
#   'goal': 2900.0,
#   'launched': datetime.datetime(2017, 11, 28, 18, 25, 15),
#   'pledged': 356.0,
#   'state': 'failed',
#   'backers': 13,
#   'country': 'DE',
#   'usd pledged': 222.97687203,
#   'usd_pledged_real': 418.01700248931473},
#  {'_id': 852739236,
#   'name': 'PUGnPLAY - Pick-Up Games / Recreational Sports Network',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-02-07',
#   'goal': 17500.0,
#   'launched': datetime.datetime(2015, 1, 3, 21, 31, 10),
#   'pledged': 16.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 16.0,
#   'usd_pledged_real': 16.0},
#  {'_id': 126588602,
#   'name': 'Behinderten gerechtes Sport/Kaj?tboot, Gr??e 10 - 12 m',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-05-25',
#   'goal': 3000000.0,
#   'launched': datetime.datetime(2016, 4, 25, 18, 6, 17),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'DE',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1262248098,
#   'name': 'ShockFlyingï¿½ eSports Start Up (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-02-25',
#   'goal': 155.0,
#   'launched': datetime.datetime(2016, 1, 11, 17, 36, 25),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 148270105,
#   'name': 'Tawny Shark: Sport Watch Inspired By Pilot And Solar System',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'CAD',
#   'deadline': '2015-09-14',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 8, 31, 2, 57, 5),
#   'pledged': 24402.0,
#   'state': 'successful',
#   'backers': 272,
#   'country': 'CA',
#   'usd pledged': 18481.0852989,
#   'usd_pledged_real': 18731.864588930683},
#  {'_id': 854211167,
#   'name': 'The Amphibious - The way of a Paralympic Sportsman',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-07-17',
#   'goal': 7420.0,
#   'launched': datetime.datetime(2016, 6, 20, 17, 4, 18),
#   'pledged': 106.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 105.0,
#   'usd_pledged_real': 106.0},
#  {'_id': 1766749777,
#   'name': 'France Retro Sport Jersey',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-07-10',
#   'goal': 375.0,
#   'launched': datetime.datetime(2016, 5, 26, 11, 10, 59),
#   'pledged': 47.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'ES',
#   'usd pledged': 52.38683309,
#   'usd_pledged_real': 52.301837241133725},
#  {'_id': 1710166877,
#   'name': 'Sausage Sports Club',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-09-07',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2016, 8, 8, 17, 36, 29),
#   'pledged': 15883.77,
#   'state': 'successful',
#   'backers': 387,
#   'country': 'US',
#   'usd pledged': 795.0,
#   'usd_pledged_real': 15883.77},
#  {'_id': 1003481744,
#   'name': 'CONDUIT Sports - Dynamic Bone Conducting Headphones',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-05-15',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2017, 4, 10, 21, 11, 10),
#   'pledged': 106213.0,
#   'state': 'successful',
#   'backers': 1052,
#   'country': 'US',
#   'usd pledged': 2478.0,
#   'usd_pledged_real': 106213.0},
#  {'_id': 109340871,
#   'name': 'Stop On Time | The Public Transport Game for all the family.',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2015-03-23',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2015, 2, 20, 21, 5, 56),
#   'pledged': 839.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'GB',
#   'usd pledged': 1296.43965551,
#   'usd_pledged_real': 1248.0476013387874},
#  {'_id': 658325991,
#   'name': 'Eliminate Tan Lines with The Vee Strapless Sports Bra',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2014-05-25',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2014, 4, 15, 22, 44, 9),
#   'pledged': 1519.0,
#   'state': 'failed',
#   'backers': 22,
#   'country': 'US',
#   'usd pledged': 1519.0,
#   'usd_pledged_real': 1519.0},
#  {'_id': 38175482,
#   'name': 'Xrossgear - The new definition of extreme sports apparel',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2011-12-12',
#   'goal': 9700.0,
#   'launched': datetime.datetime(2011, 11, 7, 6, 43, 40),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1147840746,
#   'name': 'Varsity Sports Network Makeover',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2014-12-17',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2014, 11, 17, 22, 59, 44),
#   'pledged': 100.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'_id': 2134681345,
#   'name': 'GPS DATUM Sports HD 1080p 60fps camera, Wireless Network',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'GBP',
#   'deadline': '2013-05-08',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2013, 4, 8, 19, 46, 17),
#   'pledged': 700.0,
#   'state': 'canceled',
#   'backers': 8,
#   'country': 'GB',
#   'usd pledged': 1071.047145,
#   'usd_pledged_real': 1076.8236778143557},
#  {'_id': 1547684157,
#   'name': 'S2SA - Sport to Strap Adapter for Samsung Gear S2 Sport (3G)',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-02-21',
#   'goal': 2700.0,
#   'launched': datetime.datetime(2016, 1, 22, 23, 36, 37),
#   'pledged': 909.0,
#   'state': 'failed',
#   'backers': 12,
#   'country': 'AT',
#   'usd pledged': 989.12506851,
#   'usd_pledged_real': 1000.4402377283734},
#  {'_id': 645692773,
#   'name': 'Worlds Collide Sports & Comics Bar',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-04-22',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2016, 2, 22, 20, 10, 35),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 284217830,
#   'name': 'A Fantastic New Concept for Wireless, Smart Sport Headphones',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-07-12',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2014, 6, 2, 9, 58, 5),
#   'pledged': 45321.0,
#   'state': 'canceled',
#   'backers': 84,
#   'country': 'US',
#   'usd pledged': 45321.0,
#   'usd_pledged_real': 45321.0},
#  {'_id': 523218997,
#   'name': 'HYDROSPORTï¿½ Vest : Hydration System + Fitness Pack',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-10-20',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 9, 30, 16, 3, 19),
#   'pledged': 1783.0,
#   'state': 'successful',
#   'backers': 30,
#   'country': 'US',
#   'usd pledged': 1783.0,
#   'usd_pledged_real': 1783.0},
#  {'_id': 9576483,
#   'name': 'Custom Official Sports Logo Rings - NCAA, NHL, NBA & NASCAR',
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-02-24',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2017, 1, 25, 23, 17, 46),
#   'pledged': 101.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 101.0},
#  {'_id': 792545664,
#   'name': 'SportsCard by Medical Concepts, llc',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-06-05',
#   'goal': 13500.0,
#   'launched': datetime.datetime(2016, 5, 6, 23, 3, 23),
#   'pledged': 300.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 300.0,
#   'usd_pledged_real': 300.0},
#  {'_id': 33929889,
#   'name': 'Sports podcast',
#   'category': 'Audio',
#   'main_category': 'Journalism',
#   'currency': 'CAD',
#   'deadline': '2017-08-05',
#   'goal': 250.0,
#   'launched': datetime.datetime(2017, 7, 6, 1, 11, 27),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 602521579,
#   'name': 'Transporting my ArtPrize Painting to Michigan',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-09-15',
#   'goal': 500.0,
#   'launched': datetime.datetime(2015, 9, 7, 21, 0),
#   'pledged': 575.0,
#   'state': 'successful',
#   'backers': 12,
#   'country': 'US',
#   'usd pledged': 575.0,
#   'usd_pledged_real': 575.0},
#  {'_id': 367445085,
#   'name': "The world's best Sports, Travel and Outdoor Jacket",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2018-01-24',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2017, 12, 11, 16, 5, 56),
#   'pledged': 108207.0,
#   'state': 'live',
#   'backers': 295,
#   'country': 'AT',
#   'usd pledged': 51111.37253068,
#   'usd_pledged_real': 131330.33146019685},
#  {'_id': 1224314059,
#   'name': 'Fantasy Fan Sports',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2015-10-26',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 9, 26, 21, 21, 36),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1491511986,
#   'name': 'Wild life & Nature sports',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2018-01-27',
#   'goal': 4000.0,
#   'launched': datetime.datetime(2017, 11, 28, 10, 11, 20),
#   'pledged': 0.0,
#   'state': 'live',
#   'backers': 0,
#   'country': 'ES',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1007112532,
#   'name': 'LoopBall: the first Bluetooth connected sport ball !',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-08-04',
#   'goal': 45000.0,
#   'launched': datetime.datetime(2017, 6, 20, 9, 33, 21),
#   'pledged': 4422.0,
#   'state': 'failed',
#   'backers': 48,
#   'country': 'FR',
#   'usd pledged': 961.88407928,
#   'usd_pledged_real': 5248.041775456919},
#  {'_id': 1966574528,
#   'name': 'The Sports Towel - Help take my product to market.',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-03-13',
#   'goal': 16625.0,
#   'launched': datetime.datetime(2016, 2, 12, 1, 16, 51),
#   'pledged': 261.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 261.0,
#   'usd_pledged_real': 261.0}]
